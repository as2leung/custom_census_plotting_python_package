# %% [markdown]
# # QC function - Custom Plotting Prototyping
#
# ### _Andrew Leung - Thursday March 28, 2019

# %%
# %%javascript
# $.getScript('https://kmahelona.github.io/ipython_notebook_goodies/ipython_notebook_toc.js')

# %% [markdown]
# <h1 id="tocheading">Table of Contents</h1>
# <div id="toc"></div>

# %% [markdown]
# Function Set 7 will consist of 4 different functions to allowing plotting of continuous and discrete/ordinal/nominal data:
#
# 1. Scatter Plot for continuous variables
# 2. Barplot for distributional variables
# 3. Histogram and Boxplots
# 4. Time Series/Line plots
#
#
# The following is the pseudocode/skeleton of the functions. Some of the parameters will be set to either on/off by default. Documentation to follow as code gets developed:
#
#
#
# ### Example of Input Data
# **DF** of input data:
#
# |CODE|Var1|Var2|Var3|Var4|
# |:-------------|:----------------------|:----------------------|:----------------------|:-----------------|
#
#
# ### Scatter Plot for continuous variables
#
# ```Python
#
# #list of variable pairings to scatter
# df_list= [[Var1,Var2], [Var3,Var4] ]
#
# def scatter_cont(list of lists of variable pairs to scatter, dataframe, trendline):
#     # try except for non-nested list with only two variables/one pairing: ["Var1,"Var2"]
#     try: df_list[0].type == list()
#
#
#     except:
#         #enclose unnested pair into list
#         df_list = list(df_list)
#
#
#     for pairs in range(length(df_lists)):
#         x = df_list[pairs][0]
#         y = df_list[pairs][1]
#
#         #include correlation such as pearson or spearman by implementing a function like the one in the commented block
#
#       '''
#         from scipy import stats
#         def r2(x, y):
#             return stats.pearsonr(x, y)[0] ** 2
#         sns.jointplot(x, y, kind="reg", stat_func=r2)
#       '''
#         r2(x,y)
#
#         #create plot
#         sns.scatterplot(x,y,dataframe, stat_func= r2)
#
#         #arrange plots according to length of list
#         fig, ax = plt.subplots(#, #, sharex='col', sharey='row')
#
#         #fig size autmatic adjustments
#
#         #plot axes automated configuration
#         ax.set_xlim()
#         plt.xlim(60,95)
#
#         #plot axes ticks automatically configured
#
#         #X and y-axis labels
#         x_lab = "Var1"
#         y_lab = "Var2"
#
#         #add trendline
#         abline()
#
#
# ```
#
# ### Barplot for distributional variables
#
#
# ```python
#
#
# #list of variable pairings to scatter
#
# df_list= [[Var1,Var2], [Var3,Var4] ]
#
# #Var1 and Var3 = Column with categories sorted (i.e. age 0-5, age 6-10)
# #Var2 and Var4 = Column with values
#
#
# def distrib_barplot(list of lists of variable pairs to plot, binwidth, number of bins, percent_distrib=NULL, horizontal=NULL, dataframe):
#     # try except for non-nested list with only two variables/one pairing: ["Var1,"Var2"]
#     try: df_list[0].type == list()
#
#
#     except:
#         #enclose unnested pair into list
#         df_list = list(df_list)
#
#
#     for pairs in range(length(df_lists)):
#         x = df_list[pairs][0]
#         y = df_list[pairs][1]
#
#         #create barplot
#         sns.scatterplot(x,y,dataframe)
#
#         #if horizontal requested use alternate (swap axis)
#
#         ax = sns.barplot(x= y, y= x, data=df)
#         ax.set_xlabel('y')
#
#         #set axis limits and add labelling
#         ax.legend(ncol=2, loc="lower right", frameon=True)
#         ax.set(xlim=(#, #), ylabel="",
#         xlabel="")
#
#         #use percent distribution instead
#         '''
#            perhaps and estimator=lambda x: sum(x==0)*100.0/len(x)
#
#            or use pandas to normalize
#
#         '''
#
#
# ```
#
#
# ### Histogram and Boxplots
#
# ```Python
#
#
# df_list= [Var1,Var2,Var3,Var4]
#
# def hist_box(list of variables to plot, facet variable, dataframe):
#     # try except for a non list object
#     try: df_list.type == list()
#
#
#     except:
#         #enclose into list
#         df_list = list(df_list)
#
#
#     for pairs in range(length(df_lists)):
#         x = df_list[pairs]
#         y = facet variable
#
#         #create histogram
#         sns.distplot(x,dataframe)
#
#         #create boxplot
#         sns.boxplot(x,y,dataframe)
#
# ```
#
#
# ### Time Series/Line plots
#
#
# ```Python
#
# #list of variable pairings to scatter
# df_list= [[Var1,Var2], [Var3,Var4] ]
#
# #Var1 and Var3 =  Time unit (i.e. ordered years)
# #Var2 and Var4 =  Quantity
#
#
# def time_series(list of lists of variable pairs to plot, dataframe, descriptive_stats = null):
#         # try except for non-nested list with only two variables/one pairing: ["Var1,"Var2"]
#     try: df_list[0].type == list()
#
#
#     except:
#         #enclose unnested pair into list
#         df_list = list(df_list)
#
#
#     for pairs in range(length(df_lists)):
#         x = df_list[pairs][0]
#         y = df_list[pairs][1]
#
#          #arrange plots according to length of list
#         fig, ax = plt.subplots(#, #, sharex='col', sharey='row')
#
#         #fig size autmatic adjustments
#
#         #plot axes automated configuration
#         ax.set_xlim()
#         plt.xlim(60,95)
#
#         #plot axes ticks automatically configured
#
#             '''
#             change dashes parameter
#             '''
#
#         #X and y-axis labels
#         x_lab = "Var1"
#         y_lab = "Var2"
#
#         #line plot
#         sns.lineplot(x,y, dataframe)
#
#         #add mean global trendline
#         #sns.abline()
#
#         #print descriptive stats
#         x.describe()
#
#
# ```

# %% [markdown]
# ## Function 1 - Testing

# %%
#libraries

import pandas as pd
import time as time
import seaborn as sns
from matplotlib import pyplot as plt
import csv
from scipy import stats

# %matplotlib inline

# %%
#experiment with reading csv's using csv.reader
df=[]

# read header automatically
with open("2018_da_abor.csv", "r") as f:
    reader = csv.reader(f)
    for header in reader:
        df.append(header)
        
#df[1:]

#pd.DataFrame(df, columns=df[0])

# %%
myDict =[]
        
# add row to CSV file
with open("2018_da_abor.csv", "a", newline='') as f:
    writer = csv.DictWriter(f, fieldnames=header)

# assign with open to a varaible first

csvfile = open('2018_da_abor.csv', 'r', newline='')
csvreader = csv.reader(csvfile, delimiter = ',')
for row in csvreader:
    thisVariable = row[0]
    break

# %%
#read in csv files
y2018 = pd.read_csv('2018_da_abor.csv')
y2019 = pd.read_csv('2019_da_abor.csv')

# %%
#test function for try and except
def scatter_cont(lists, df_new, df_old):
    try:
        isinstance(lists, (list,))==True
    except:
        print("not a list") 
        '''
        try:
            type(lists[0])=='list'
        except ExplicitException:
            print("list of lists needed")
       
        combined = df_new.merge(df_old, how='inner', left_on='CODE', right_on='CODE', suffixes=("_x","_y"))
        print(combined)
            
       ''' 

# Using this method with isinstance() did not work as expected, as the "False" returned does not result in triggering the
# exception. We need something to trigger an error in python.

# %%
def scatter_cont2(lists):
    try:
#         if isinstance(lists[0], list)==True:
#             print('list in a list')
#         else:
#             print('nah g')
        var1 = lists[0]
    
        print('do my plotting')
    except:
        print("not a list") 
        
        '''
        try:
            type(lists[0])=='list'
        except ExplicitException:
            print("list of lists needed")
       
        combined = df_new.merge(df_old, how='inner', left_on='CODE', right_on='CODE', suffixes=("_x","_y"))
        print(combined)
            
       ''' 
        print('do something')

This method proposed by Layne indexes into the variable provided as if it were a list. If it fails to index properly, it
# Out:
#   File "<ipython-input-66-d75a71ea86ae>", line 25
#     This method proposed by Layne indexes into the variable provided as if it were a list. If it fails to index properly, it
#               ^
# SyntaxError: invalid syntax

# %%
#testing plots with sns.scatterplot

lists=[["AITOT","AITOT"],["AINABOR","AINABOR"],["AIABOR","AIABOR"]]
combined = y2019.merge(y2018, how='inner', left_on='CODE', right_on='CODE', suffixes=("_x","_y"))

#display(combined)
#fig, ax = plt.subplots(len(lists), 2,figsize=(15,6))


for pairs in range(len(lists)):
    x = lists[pairs][0]+"_x"
    y = lists[pairs][1]+"_y"
    f,ax = plt.subplots(figsize=(15,6))
    ax.set(xscale="log", yscale="log")
    r2 = stats.pearsonr(combined[x],combined[y])[0]**2
    r2a = stats.pearsonr(combined[x],combined[y])[1]
    sns.scatterplot(x=x,y=y,data = combined, ax=ax)#, ax=ax[pairs][1])
    #sns.regplot(x=x,y=y,data = combined,scatter_kws={'alpha':0.03})
    #set title
    print("\n\n\n\n")
    plt.suptitle('Scatter of {} vs {}'.format(x,y),fontsize=18, ha='center')
    plt.title('R-Squared: {}, P-value: {}'.format(r2, r2a),ha='center')
    plt.show()

    
    #ax.text(x=0.5, y=1.05,s='The size of each point corresponds to sepal width',fontsize=8, alpha=0.75, ha='center',va='bottom', 
    #         transform=ax.transAxes)


# Below     
#     fig, ax = plt.subplots(2, 2, sharex='col', sharey='row')

# #axes are in a two-dimensional array, indexed by [row, col]
# for i in range(0):
#     for j in range(2):
#         ax[i, j].text(0.5, 0.5, str((i, j)),fontsize=18, ha='center')
# fig
# ax

# %%
#normalized version

for pairs in range(len(lists)):
    x = lists[pairs][0]+"_x"
    y = lists[pairs][1]+"_y"
    combined[x] = combined[x]/combined[x].sum()*100
    combined[y] = combined[y]/combined[y].sum()*100
    f,ax = plt.subplots(figsize=(15,6))
    ax.set(xscale="log", yscale="log")
    r2 = stats.pearsonr(combined[x],combined[y])[0]**2
    r2a = stats.pearsonr(combined[x],combined[y])[1]
    sns.scatterplot(x=x,y=y,data = combined, ax=ax)#, ax=ax[pairs][1])
    #sns.regplot(x=x,y=y,data = combined,scatter_kws={'alpha':0.03})
    #set title
    print("\n\n\n\n")
    plt.suptitle('Scatter of {} vs {}'.format(x,y),fontsize=18, ha='center')
    plt.title('R-Squared: {}, P-value: {}'.format(r2, r2a),ha='center')
    plt.show()

    
    #ax.text(x=0.5, y=1.05,s='The size of each point corresponds to sepal width',fontsize=8, alpha=0.75, ha='center',va='bottom', 
    #         transform=ax.transAxes)


# Below     
#     fig, ax = plt.subplots(2, 2, sharex='col', sharey='row')

# #axes are in a two-dimensional array, indexed by [row, col]
# for i in range(0):
#     for j in range(2):
#         ax[i, j].text(0.5, 0.5, str((i, j)),fontsize=18, ha='center')
# fig
# ax

# %%
#testing sns.regplot for linear trend

for pairs in range(len(lists)):
    x = lists[pairs][0]+"_x"
    y = lists[pairs][1]+"_y"
    f,ax = plt.subplots(figsize=(15,6))
    ax.set(xscale="log", yscale="log")
    r2 = stats.pearsonr(combined[x],combined[y])[0]**2
    r2a = stats.pearsonr(combined[x],combined[y])[1]
    sns.scatterplot(x=x,y=y,data = combined, ax=ax)#, ax=ax[pairs][1])
    sns.regplot(x=x,y=y,data = combined,scatter_kws={'alpha':0.05})
    #set title
    print("\n\n\n\n")
    plt.suptitle('Scatter of {} vs {}'.format(x,y),fontsize=18, ha='center')
    plt.title('R-Squared: {}, P-value: {}'.format(r2, r2a),ha='center')
    plt.show()

# %%
def scatter_cont3(lists,df_new,df_old, join_field, normalized=True, linear_trend=False):
    test=1
    try:
        var1 = lists[0]
        
    except:
        test=0
        print('we out')
        return False
    
    try:
        var2 = lists[0][1]
        
    except:
        test=0
        print('we out still')
        
    else:
        
        combined = df_new.merge(df_old, how='inner', left_on='{}'.format(join_field), right_on='{}'.format(join_field), suffixes=("_new","_old"))
        return combined
            
    finally:
        
        if normalized==True:
            if linear_trend==True:
                print('Add linear trend')

                for pairs in range(len(lists)):
                    x = lists[pairs][0]+"_new"
                    y = lists[pairs][1]+"_old"
                    combined[x] = combined[x]/combined[x].sum()*100
                    combined[y] = combined[y]/combined[y].sum()*100
                    f,ax = plt.subplots(figsize=(15,6))
                    r2 = stats.pearsonr(combined[x],combined[y])[0]**2
                    r2a = stats.pearsonr(combined[x],combined[y])[1]
                    sns.scatterplot(x=x,y=y,data = combined, ax=ax)#, ax=ax[pairs][1])
                    sns.regplot(x=x,y=y,data = combined,scatter_kws={'alpha':0.03})
                    #set title
                    print("\n\n\n\n")
                    plt.suptitle('Scatter of {} vs {}'.format(x,y),fontsize=18, ha='center')
                    plt.title('R-Squared: {}, P-value: {}'.format(r2, r2a),ha='center')
                    plt.show()

            else:

                print('No linear trend')
                for pairs in range(len(lists)):
                    x = lists[pairs][0]+"_new"
                    y = lists[pairs][1]+"_old"
                    combined[x] = combined[x]/combined[x].sum()*100
                    combined[y] = combined[y]/combined[y].sum()*100
                    f,ax = plt.subplots(figsize=(15,6))
                    r2 = stats.pearsonr(combined[x],combined[y])[0]**2
                    r2a = stats.pearsonr(combined[x],combined[y])[1]
                    sns.scatterplot(x=x,y=y,data = combined, ax=ax)#, ax=ax[pairs][1])
                    #sns.regplot(x=x,y=y,data = combined,scatter_kws={'alpha':0.03})
                    #set title
                    print("\n\n\n\n")
                    plt.suptitle('Scatter of {} vs {}'.format(x,y),fontsize=18, ha='center')
                    plt.title('R-Squared: {}, P-value: {}'.format(r2, r2a),ha='center')
                    plt.show()
        else:
            if linear_trend==True:
                print('Add linear trend')

                for pairs in range(len(lists)):
                    x = lists[pairs][0]+"_new"
                    y = lists[pairs][1]+"_old"
                    f,ax = plt.subplots(figsize=(15,6))
                    r2 = stats.pearsonr(combined[x],combined[y])[0]**2
                    r2a = stats.pearsonr(combined[x],combined[y])[1]
                    sns.scatterplot(x=x,y=y,data = combined, ax=ax)#, ax=ax[pairs][1])
                    sns.regplot(x=x,y=y,data = combined,scatter_kws={'alpha':0.03})
                    #set title
                    print("\n\n\n\n")
                    plt.suptitle('Scatter of {} vs {}'.format(x,y),fontsize=18, ha='center')
                    plt.title('R-Squared: {}, P-value: {}'.format(r2, r2a),ha='center')
                    plt.show()

            else:

                print('No linear trend')
                for pairs in range(len(lists)):
                    x = lists[pairs][0]+"_new"
                    y = lists[pairs][1]+"_old"
                    f,ax = plt.subplots(figsize=(15,6))
                    r2 = stats.pearsonr(combined[x],combined[y])[0]**2
                    r2a = stats.pearsonr(combined[x],combined[y])[1]
                    sns.scatterplot(x=x,y=y,data = combined, ax=ax)#, ax=ax[pairs][1])
                    #sns.regplot(x=x,y=y,data = combined,scatter_kws={'alpha':0.03})
                    #set title
                    print("\n\n\n\n")
                    plt.suptitle('Scatter of {} vs {}'.format(x,y),fontsize=18, ha='center')
                    plt.title('R-Squared: {}, P-value: {}'.format(r2, r2a),ha='center')
                    plt.show()
            
            



    
    
        
    
 #   if test:
      #  print('stuff')

# %%
scatter_cont3(tested2,y2019,y2018,'CODE',False,True)
# Out:
# Add linear trend
#            CODE  AITOT_new  AIABOR_new  AINABOR_new  AITOT_old  AIABOR_old  \
# 0      10010165        515          19          496        567          30
# 1      10010166        328           0          328        327          12
# 2      10010167        442          41          401        447           5
# 3      10010168        531          11          520        550          20
# 4      10010169        317           0          317        315           7
# 5      10010170        403          28          375        396          23
# 6      10010171        489          14          475        488          11
# 7      10010172        228           2          226        226           8
# 8      10010173        907           9          898        904          19
# 9      10010174        883          58          825        913          86
# 10     10010175        979          46          933       1014           6
# 11     10010176        433          11          422        440           7
# 12     10010180        542           9          533        697          19
# 13     10010181        376           0          376        373           0
# 14     10010182        371          26          345        366          10
# 15     10010187        679          64          615        692           2
# 16     10010191        659           3          656        780           1
# 17     10010192        292          20          272        319          10
# 18     10010193        464           1          463        492          45
# 19     10010194        224          19          205        252           7
# 20     10010195        851          17          834        692           2
# 21     10010196        522          17          505        548          13
# 22     10010198        441           9          432        436           6
# 23     10010199        243           4          239        219           1
# 24     10010200        418           4          414        429           5
# 25     10010201        471          17          454        493           4
# 26     10010202        448           9          439        462           3
# 27     10010203        338           6          332        361           9
# 28     10010204        553           2          551        591          14
# 29     10010206        920          61          859        846           6
# ...         ...        ...         ...          ...        ...         ...
# 56560  62040068       1016         939           77        961         923
# 56561  62040069       1210        1138           72       1128        1075
# 56562  62040070        686         656           30        629         609
# 56563  62040071        804         771           33        785         701
# 56564  62040072        337         337            0        334         288
# 56565  62050012       1173        1129           44       1137        1110
# 56566  62050013          0           0            0          0           0
# 56567  62050014        483         460           23        443         391
# 56568  62050015        943         906           37        933         892
# 56569  62050017        452         430           22        459         449
# 56570  62050020       1714        1402          312       1527        1262
# 56571  62050021       1267        1081          186       1416        1122
# 56572  62050022        951         839          112        942         868
# 56573  62050023        731         715           16        722         662
# 56574  62050024        509         478           31        501         467
# 56575  62050025       1510        1456           54       1491        1415
# 56576  62050026        604         548           56        518         482
# 56577  62050027        741         721           20        786         753
# 56578  62080015          0           0            0          0           0
# 56579  62080017       1156        1110           46       1094        1028
# 56580  62080018       1042        1002           40       1017         970
# 56581  62080020          0           0            0          0           0
# 56582  62080021          5           5            0          5           2
# 56583  62080022        785         523          262        766         574
# 56584  62080023        643         559           84        615         504
# 56585  62080024        495         359          136        486         365
# 56586  62080025        574         517           57        567         456
# 56587  62080026       1049         946          103       1019         912
# 56588  62080027        854         813           41        816         764
# 56589  62080028        563         555            8        566         561
#
#        AINABOR_old
# 0              537
# 1              315
# 2              442
# 3              530
# 4              308
# 5              373
# 6              477
# 7              218
# 8              885
# 9              827
# 10            1008
# 11             433
# 12             678
# 13             373
# 14             356
# 15             690
# 16             779
# 17             309
# 18             447
# 19             245
# 20             690
# 21             535
# 22             430
# 23             218
# 24             424
# 25             489
# 26             459
# 27             352
# 28             577
# 29             840
# ...            ...
# 56560           38
# 56561           53
# 56562           20
# 56563           84
# 56564           46
# 56565           27
# 56566            0
# 56567           52
# 56568           41
# 56569           10
# 56570          265
# 56571          294
# 56572           74
# 56573           60
# 56574           34
# 56575           76
# 56576           36
# 56577           33
# 56578            0
# 56579           66
# 56580           47
# 56581            0
# 56582            3
# 56583          192
# 56584          111
# 56585          121
# 56586          111
# 56587          107
# 56588           52
# 56589            5
#
# [56590 rows x 7 columns]

# %%
def one_df_scatter_cont3(lists,df_new,df_old, join_field, normalized=True, linear_trend=False):
    test=1
    try:
        var1 = lists[0]
        
    except:
        test=0
        print('we out')
        return False
    
    try:
        var2 = lists[0][1]
        
    except:
        test=0
        print('we out still')
        
    else:
        
        combined = df_new.merge(df_old, how='inner', left_on='{}'.format(join_field), right_on='{}'.format(join_field), suffixes=("_new","_old"))
        return combined
            
    finally:
        
        if normalized==True:
            if linear_trend==True:
                print('Add linear trend')

                for pairs in range(len(lists)):
                    x = lists[pairs]+"_new"
                    y = lists[pairs]+"_old"
                    combined[x] = combined[x]/combined[x].sum()*100
                    combined[y] = combined[y]/combined[y].sum()*100
                    f,ax = plt.subplots(figsize=(15,6))
                    r2 = stats.pearsonr(combined[x],combined[y])[0]**2
                    r2= r2.round(2)
                    r2a = stats.pearsonr(combined[x],combined[y])[1]
                    r2a = r2a.round(2)
                    sns.scatterplot(x=x,y=y,data = combined, ax=ax)#, ax=ax[pairs][1])
                    sns.regplot(x=x,y=y,data = combined,scatter_kws={'alpha':0.03})
                    #set title
                    print("\n\n\n\n")
                    plt.suptitle('Scatter of {} vs {}'.format(x,y),fontsize=18, ha='center')
                    plt.title('R-Squared: {}, P-value: {}'.format(r2, r2a),ha='center')
                    plt.show()

            else:

                print('No linear trend')
                for pairs in range(len(lists)):
                    x = lists[pairs]+"_new"
                    y = lists[pairs]+"_old"
                    combined[x] = combined[x]/combined[x].sum()*100
                    combined[y] = combined[y]/combined[y].sum()*100
                    f,ax = plt.subplots(figsize=(15,6))
                    r2 = stats.pearsonr(combined[x],combined[y])[0]**2
                    r2= r2.round(2)
                    r2a = stats.pearsonr(combined[x],combined[y])[1]
                    r2a = r2a.round(2)
                    sns.scatterplot(x=x,y=y,data = combined, ax=ax)#, ax=ax[pairs][1])
                    #sns.regplot(x=x,y=y,data = combined,scatter_kws={'alpha':0.03})
                    #set title
                    print("\n\n\n\n")
                    plt.suptitle('Scatter of {} vs {}'.format(x,y),fontsize=18, ha='center')
                    plt.title('R-Squared: {}, P-value: {}'.format(r2, r2a),ha='center')
                    plt.show()
        else:
            if linear_trend==True:
                print('Add linear trend')

                for pairs in range(len(lists)):
                    x = lists[pairs]+"_new"
                    y = lists[pairs]+"_old"
                    f,ax = plt.subplots(figsize=(15,6))
                    r2 = stats.pearsonr(combined[x],combined[y])[0]**2
                    r2= r2.round(2)
                    r2a = stats.pearsonr(combined[x],combined[y])[1]
                    r2a= r2a.round(2)
                    sns.scatterplot(x=x,y=y,data = combined, ax=ax)#, ax=ax[pairs][1])
                    sns.regplot(x=x,y=y,data = combined,scatter_kws={'alpha':0.03})
                    #set title
                    print("\n\n\n\n")
                    plt.suptitle('Scatter of {} vs {}'.format(x,y),fontsize=18, ha='center')
                    plt.title('R-Squared: {}, P-value: {}'.format(r2, r2a),ha='center')
                    plt.show()

            else:

                print('No linear trend')
                for pairs in range(len(lists)):
                    x = lists[pairs]+"_new"
                    y = lists[pairs]+"_old"
                    f,ax = plt.subplots(figsize=(15,6))
                    r2 = stats.pearsonr(combined[x],combined[y])[0]**2
                    r2= r2.round(2)
                    r2a = stats.pearsonr(combined[x],combined[y])[1]
                    r2a= r2a.round(2)
                    sns.scatterplot(x=x,y=y,data = combined, ax=ax)#, ax=ax[pairs][1])
                    #sns.regplot(x=x,y=y,data = combined,scatter_kws={'alpha':0.03})
                    #set title
                    print("\n\n\n\n")
                    plt.suptitle('Scatter of {} vs {}'.format(x,y),fontsize=18, ha='center')
                    plt.title('R-Squared: {}, P-value: {}'.format(r2, r2a),ha='center')
                    plt.show()
            
            



    
    
        
    
 #   if test:
      #  print('stuff')

# %%
tested3 = list(y2019)
tested3.remove('CODE')
tested3

# for item in tested3:
#     print(item)

one_df_scatter_cont3(tested3,y2019,y2018,'CODE',False,False)
# Out:
# No linear trend
#            CODE  AITOT_new  AIABOR_new  AINABOR_new  AITOT_old  AIABOR_old  \
# 0      10010165        515          19          496        567          30
# 1      10010166        328           0          328        327          12
# 2      10010167        442          41          401        447           5
# 3      10010168        531          11          520        550          20
# 4      10010169        317           0          317        315           7
# 5      10010170        403          28          375        396          23
# 6      10010171        489          14          475        488          11
# 7      10010172        228           2          226        226           8
# 8      10010173        907           9          898        904          19
# 9      10010174        883          58          825        913          86
# 10     10010175        979          46          933       1014           6
# 11     10010176        433          11          422        440           7
# 12     10010180        542           9          533        697          19
# 13     10010181        376           0          376        373           0
# 14     10010182        371          26          345        366          10
# 15     10010187        679          64          615        692           2
# 16     10010191        659           3          656        780           1
# 17     10010192        292          20          272        319          10
# 18     10010193        464           1          463        492          45
# 19     10010194        224          19          205        252           7
# 20     10010195        851          17          834        692           2
# 21     10010196        522          17          505        548          13
# 22     10010198        441           9          432        436           6
# 23     10010199        243           4          239        219           1
# 24     10010200        418           4          414        429           5
# 25     10010201        471          17          454        493           4
# 26     10010202        448           9          439        462           3
# 27     10010203        338           6          332        361           9
# 28     10010204        553           2          551        591          14
# 29     10010206        920          61          859        846           6
# ...         ...        ...         ...          ...        ...         ...
# 56560  62040068       1016         939           77        961         923
# 56561  62040069       1210        1138           72       1128        1075
# 56562  62040070        686         656           30        629         609
# 56563  62040071        804         771           33        785         701
# 56564  62040072        337         337            0        334         288
# 56565  62050012       1173        1129           44       1137        1110
# 56566  62050013          0           0            0          0           0
# 56567  62050014        483         460           23        443         391
# 56568  62050015        943         906           37        933         892
# 56569  62050017        452         430           22        459         449
# 56570  62050020       1714        1402          312       1527        1262
# 56571  62050021       1267        1081          186       1416        1122
# 56572  62050022        951         839          112        942         868
# 56573  62050023        731         715           16        722         662
# 56574  62050024        509         478           31        501         467
# 56575  62050025       1510        1456           54       1491        1415
# 56576  62050026        604         548           56        518         482
# 56577  62050027        741         721           20        786         753
# 56578  62080015          0           0            0          0           0
# 56579  62080017       1156        1110           46       1094        1028
# 56580  62080018       1042        1002           40       1017         970
# 56581  62080020          0           0            0          0           0
# 56582  62080021          5           5            0          5           2
# 56583  62080022        785         523          262        766         574
# 56584  62080023        643         559           84        615         504
# 56585  62080024        495         359          136        486         365
# 56586  62080025        574         517           57        567         456
# 56587  62080026       1049         946          103       1019         912
# 56588  62080027        854         813           41        816         764
# 56589  62080028        563         555            8        566         561
#
#        AINABOR_old
# 0              537
# 1              315
# 2              442
# 3              530
# 4              308
# 5              373
# 6              477
# 7              218
# 8              885
# 9              827
# 10            1008
# 11             433
# 12             678
# 13             373
# 14             356
# 15             690
# 16             779
# 17             309
# 18             447
# 19             245
# 20             690
# 21             535
# 22             430
# 23             218
# 24             424
# 25             489
# 26             459
# 27             352
# 28             577
# 29             840
# ...            ...
# 56560           38
# 56561           53
# 56562           20
# 56563           84
# 56564           46
# 56565           27
# 56566            0
# 56567           52
# 56568           41
# 56569           10
# 56570          265
# 56571          294
# 56572           74
# 56573           60
# 56574           34
# 56575           76
# 56576           36
# 56577           33
# 56578            0
# 56579           66
# 56580           47
# 56581            0
# 56582            3
# 56583          192
# 56584          111
# 56585          121
# 56586          111
# 56587          107
# 56588           52
# 56589            5
#
# [56590 rows x 7 columns]

# %% [markdown]
# ----

# %% [markdown]
# ## Function 2 - Testing

# %%
y2018d = pd.read_csv('2018_da_agef.csv')
y2019d =pd.read_csv('2019_da_agef.csv')

# %%
y2018d.head()
# Out:
#        CODE  PFTOT  PF0004  PF0509  PF1014  PF1519  PF2024  PF2529  PF3034  \
# 0  10010165    262       5       5       8      14      15      25      14
# 1  10010166    161       4       2       3      10      10      13       7
# 2  10010167    221       6       8       9      14      15      14       6
# 3  10010168    270       8      14       8      11      15      20      11
# 4  10010169    141       4       5       6       5      13      13       5
#
#    PF3539  PF4044  PF4549  PF5054  PF5559  PF6064  PF6569  PF7074  PF7579  \
# 0      14      14      11      24      26      31      24      15       5
# 1       9       8       7      10      15      17      16      15       7
# 2      11      15       9      14      22      24      26      17       4
# 3      19      16      16      19      21      25      26      20       9
# 4       6       7       5      14      17      12      12       8       2
#
#    PF8084  PF85P
# 0       8      4
# 1       6      2
# 2       3      4
# 3       6      6
# 4       3      4

# %%
y2019d.head()
# Out:
#        CODE  PFTOT  PF0004  PF0509  PF1014  PF1519  PF2024  PF2529  PF3034  \
# 0  10010165    262       5       6       8      13      15      23      14
# 1  10010166    159       3       3       3       8      10      13       7
# 2  10010167    222       6       8       9      13      15      15       7
# 3  10010168    270       9      13       9      11      14      20      11
# 4  10010169    141       4       5       6       6      11      13       6
#
#    PF3539  PF4044  PF4549  PF5054  PF5559  PF6064  PF6569  PF7074  PF7579  \
# 0      14      15      11      22      26      30      26      17       6
# 1       9       8       7      10      14      17      17      15       7
# 2      10      14      10      14      20      24      26      19       6
# 3      18      17      15      19      20      25      26      21       9
# 4       6       7       5      12      16      13      12       9       3
#
#    PF8084  PF85P
# 0       7      4
# 1       6      2
# 2       3      3
# 3       7      6
# 4       3      4

# %%
Geo_list = list(y2019d.CODE)

import random as random
random.sample(Geo_list,10)
# Out:
# [35260665,
#  59090614,
#  35250680,
#  48010151,
#  59151929,
#  47070157,
#  48100209,
#  59090626,
#  47060623,
#  35181110]

# %%
sub_set=[random.sample(Geo_list,10)]
sub_set
# Out:
# [[35210189,
#   48140061,
#   48060416,
#   35140191,
#   35070169,
#   35260494,
#   24662706,
#   35060308,
#   46110382,
#   48010188]]

# %%
def distrib_plot(df_new,df_old,join_field, difference = False, normalized = False,
                 placement='grouped'):
    test=1
#     try:
#         var1 = lists[0]
        
#     except:
#         test=0
#         print('we out')
#         return False
    
#     try:
#         var2 = lists[0][1]
        
#     except:
#         test=0
#         print('we out still')
        
#     else:
        
    combined = df_new.merge(df_old, how='inner', left_on='{}'.format(join_field), right_on='{}'.format(join_field), suffixes=("_new","_old"))
    combined['CODE'] = combined['CODE'].astype(str)

            
#     finally:
       
    if difference == True:
        vars = list(df_old)
        vars.remove("CODE")
        vars

        df_diff = pd.DataFrame(df_old["CODE"])

        for var in vars:
            df_diff["diff_"+var] = df_new[var]-df_old[var]

        df_diff.dropna(inplace = True )
        df_diff['CODE'] = df_diff['CODE'].astype(str)

        Geo_list = list(combined.CODE)
        sub_set=[i for i in random.sample(Geo_list,2)]
        final_df = df_diff[df_diff['CODE'].isin(sub_set)]
        sub_set.sort()
        print(sub_set)
        print(final_df)



        for s in sub_set:

            final_df_t = pd.melt(final_df,id_vars=['CODE'])

            final_df_t = final_df_t[final_df_t['CODE']==s]
            print(final_df_t)

            g = sns.catplot(x="variable", y="value", data=final_df_t,height=10, kind="bar", palette="muted", aspect =1.3)

            g.set_xticklabels(rotation=30)

            ax = plt.gca()

            for p in ax.patches:
                ax.text(p.get_x() + p.get_width()/2., p.get_height(), '%d' % int(p.get_height()), 
                        fontsize=10, color='black', ha='center', va='bottom')


    ######
    else:

        Geo_list = list(combined.CODE)
        sub_set=[i for i in random.sample(Geo_list,10)]
        final_df = combined[combined['CODE'].isin(sub_set)]
        sub_set.sort()
        #print(sub_set)

        for s in sub_set:


            final_df_t = pd.melt(final_df,id_vars=['CODE'])
            return final_df_t
           

            final_df_t = final_df_t[final_df_t['CODE']==s]


            final_df_t['Flag']= final_df_t['variable'].apply(lambda x: x.split("_")[1])
            final_df_t['variable']= final_df_t['variable'].apply(lambda x: x.split("_")[0])
            
            

            if normalized == False: 

                print(final_df_t)


                if placement == "grouped":
                    g = sns.catplot(x="variable", y="value", hue="Flag", data=final_df_t, 
                                height=10, kind="bar", palette="muted", aspect =1.3)

                    ax = plt.gca()

                    for p in ax.patches:
                        ax.text(p.get_x() + p.get_width()/2., p.get_height(), '%d' % int(p.get_height()), 
                                fontsize=10, color='black', ha='center', va='bottom')

                elif placement == "split":

                    g = sns.FacetGrid(final_df_t, row = "Flag", size=10, aspect=1.3)
                    g.map(sns.barplot, "variable", "value")

                    ax = plt.gca()

                    for p in ax.patches:
                        ax.text(p.get_x() + p.get_width()/2., p.get_height(), '%d' % int(p.get_height()), 
                                fontsize=10, color='black', ha='center', va='bottom')
                
                elif placement == "series":
                    plt.figure(figsize=(15,16)) 

                    g = sns.pointplot(x="variable", y="value", hue="Flag", data=final_df_t,
                                    height=10, kind="bar", palette="muted", aspect =1.3)


                    ax = plt.gca()
                    
                    plt.show()

            elif normalized == True:

                final_df_t = final_df_t.assign(normalized=final_df_t.value.div(final_df_t.Flag.map(final_df_t.groupby('Flag').value.sum()))*100)
                print(final_df_t)

                if placement == "grouped":

                    g = sns.catplot(x="variable", y="normalized", hue="Flag", data=final_df_t,
                                height=10, kind="bar", palette="muted", aspect =1.3)

                    ax = plt.gca()

                    for p in ax.patches:
                        for p in ax.patches:
                             ax.annotate(round(p.get_height(),3), (p.get_x() * 1.005, p.get_height() * 1.005), rotation=90 )

                elif placement == "split":

                    g = sns.FacetGrid(final_df_t, row = "Flag", size=10, aspect=1.3)
                    g.map(sns.barplot, "variable", "normalized")

                    ax = plt.gca()

                    for p in ax.patches:
                        for p in ax.patches:
                             ax.annotate(round(p.get_height(),3), (p.get_x() * 1.005, p.get_height() * 1.005))

                elif placement == "series":
                    plt.figure(figsize=(15,16)) 

                    g = sns.pointplot(x="variable", y="normalized", hue="Flag", data=final_df_t,
                                    height=10, kind="bar", palette="muted", aspect =1.3)


                    ax = plt.gca()
                    
                    plt.show()

# %%
tranposed = distrib_plot(y2019d,y2018d,'CODE', difference=False, normalized = True, placement='series')
tranposed['Flag']= tranposed['variable'].apply(lambda x: x.split("_")[1])
tranposed['variable']= tranposed['variable'].apply(lambda x: x.split("_")[0])
tranposed.head()
# Out:
#        CODE variable  value Flag
# 0  24450149    PFTOT    235  new
# 1  35190482    PFTOT    148  new
# 2  35240816    PFTOT    298  new
# 3  35580476    PFTOT    282  new
# 4  48061189    PFTOT    249  new

# %%
def distrib_plot_v2(df_new,df_old,join_field, difference = False, normalized = False,
                 placement='grouped', universe ="", sample_size=10):
    test=1
#     try:
#         var1 = lists[0]
        
#     except:
#         test=0
#         print('we out')
#         return False
    
#     try:
#         var2 = lists[0][1]
        
#     except:
#         test=0
#         print('we out still')
        
#     else:
    if not universe =="":
        df_new.drop(columns=universe, inplace=True)
        df_old.drop(columns=universe, inplace=True)
        
        
    combined = df_new.merge(df_old, how='inner', left_on='{}'.format(join_field), right_on='{}'.format(join_field), suffixes=("_new","_old"))
    combined['CODE'] = combined['CODE'].astype(str)

            
#     finally:

    ######
    if normalized == False:
        
                      
        if difference == True:
            vars = list(df_old)
            vars.remove("CODE")
            vars

            df_diff = pd.DataFrame(df_old["CODE"])

            for var in vars:
                df_diff["diff_"+var] = df_new[var]-df_old[var]

            df_diff.dropna(inplace = True )
            df_diff['CODE'] = df_diff['CODE'].astype(str)

            Geo_list = list(combined.CODE)
            
            Geo_list.remove
            
            sub_set=[i for i in random.sample(Geo_list,sample_size)]
            final_df = df_diff[df_diff['CODE'].isin(sub_set)]
            sub_set.sort()
            #print(sub_set)
            display(final_df)



            for s in sub_set:

                final_df_t = pd.melt(final_df,id_vars=['CODE'])

                final_df_t = final_df_t[final_df_t['CODE']==s]
                print(final_df_t)

                g = sns.catplot(x="variable", y="value", data=final_df_t,height=10, kind="bar", palette="muted", aspect =1.3)

                g.set_xticklabels(rotation=30)

                ax = plt.gca()
                
                plt.title('{}'.format(s),ha='center')

                for p in ax.patches:
                    ax.text(p.get_x() + p.get_width()/2., p.get_height(), '%d' % int(p.get_height()), 
                            fontsize=10, color='black', ha='center', va='bottom')
                plt.show()
                
        else:
                             
            Geo_list = list(combined.CODE)
            sub_set=[i for i in random.sample(Geo_list,sample_size)]
            final_df = combined[combined['CODE'].isin(sub_set)]
            sub_set.sort()
            #print(sub_set)

            for s in sub_set:


                final_df_t = pd.melt(final_df,id_vars=['CODE'])

                final_df_t = final_df_t[final_df_t['CODE']==s]


                final_df_t['Flag']= final_df_t['variable'].apply(lambda x: x.split("_")[1])
                final_df_t['variable']= final_df_t['variable'].apply(lambda x: x.split("_")[0])

                


        

                display(final_df_t)


                if placement == "grouped":
                    g = sns.catplot(x="variable", y="value", hue="Flag", data=final_df_t, 
                                height=10, kind="bar", palette="muted", aspect =1.3)

                    ax = plt.gca()
                    
                    plt.title('{}'.format(s),ha='center')

                    for p in ax.patches:
                        ax.text(p.get_x() + p.get_width()/2., p.get_height(), '%d' % int(p.get_height()), 
                                fontsize=10, color='black', ha='center', va='bottom')
                    
                    plt.show()

                elif placement == "split":

                    g = sns.FacetGrid(final_df_t, row = "Flag", size=10, aspect=1.3)
                    g.map(sns.barplot, "variable", "value")

                    ax = plt.gca()
                    
                    plt.title('{}'.format(s),ha='center')

                    for p in ax.patches:
                        ax.text(p.get_x() + p.get_width()/2., p.get_height(), '%d' % int(p.get_height()), 
                                fontsize=10, color='black', ha='center', va='bottom')
                    
                    plt.show()

                elif placement == "series":
                    plt.figure(figsize=(15,16)) 

                    g = sns.pointplot(x="variable", y="value", hue="Flag", data=final_df_t,
                                    height=10, kind="bar", palette="muted", aspect =1.3)


                    ax = plt.gca()
                    
                    plt.title('{}'.format(s),ha='center')

                    plt.show()

    elif normalized == True:


        if difference == True:
            vars = list(df_old)
            vars.remove("CODE")
            vars

            df_diff = pd.DataFrame(df_old["CODE"])

            for var in vars:
                df_diff["diff_"+var] = (df_new[var]-df_old[var])/df_new[var]*100

            df_diff.dropna(inplace = True )
            df_diff['CODE'] = df_diff['CODE'].astype(str)

            Geo_list = list(combined.CODE)
            sub_set=[i for i in random.sample(Geo_list,sample_size)]
            final_df = df_diff[df_diff['CODE'].isin(sub_set)]
            sub_set.sort()
            #(sub_set)
            display(final_df)



            for s in sub_set:

                final_df_t = pd.melt(final_df,id_vars=['CODE'])

                final_df_t = final_df_t[final_df_t['CODE']==s]
                print(final_df_t)

                g = sns.catplot(x="variable", y="value", data=final_df_t,height=10, kind="bar", palette="muted", aspect =1.3)

                g.set_xticklabels(rotation=30)

                ax = plt.gca()

                for p in ax.patches:
                    ax.text(p.get_x() + p.get_width()/2., p.get_height(), '%d' % int(p.get_height()), 
                            fontsize=10, color='black', ha='center', va='bottom')
                
                plt.show()

        else:

            Geo_list = list(combined.CODE)
            sub_set=[i for i in random.sample(Geo_list,2)]
            final_df = combined[combined['CODE'].isin(sub_set)]
            sub_set.sort()
            #print(sub_set)

            for s in sub_set:


                final_df_t = pd.melt(final_df,id_vars=['CODE'])

                final_df_t = final_df_t[final_df_t['CODE']==s]


                final_df_t['Flag']= final_df_t['variable'].apply(lambda x: x.split("_")[1])
                final_df_t['variable']= final_df_t['variable'].apply(lambda x: x.split("_")[0])
                
                             
                
                final_df_t = final_df_t.assign(normalized=final_df_t.value.div(final_df_t.Flag.map(final_df_t.groupby('Flag').value.sum()))*100)
                display(final_df_t)

                if placement == "grouped":

                    g = sns.catplot(x="variable", y="normalized", hue="Flag", data=final_df_t,
                                height=10, kind="bar", palette="muted", aspect =1.3)

                    ax = plt.gca()
                    
                    plt.title('{}'.format(s),ha='center')

                    for p in ax.patches:
                        for p in ax.patches:
                             ax.annotate(round(p.get_height(),3), (p.get_x() * 1.005, p.get_height() * 1.005), rotation=90 )
                    
                    plt.show()

                elif placement == "split":

                    g = sns.FacetGrid(final_df_t, row = "Flag", size=10, aspect=1.3)
                    g.map(sns.barplot, "variable", "normalized")

                    ax = plt.gca()
                    
                    plt.title('{}'.format(s),ha='center')

                    for p in ax.patches:
                        for p in ax.patches:
                             ax.annotate(round(p.get_height(),3), (p.get_x() * 1.005, p.get_height() * 1.005))
                    
                    plt.show()

                elif placement == "series":
                    plt.figure(figsize=(15,16)) 

                    g = sns.pointplot(x="variable", y="normalized", hue="Flag", data=final_df_t,
                                    height=10, kind="bar", palette="muted", aspect =1.3)


                    ax = plt.gca()
                    plt.title('{}'.format(s),ha='center')
                    
                    plt.show()

# %%
geolist = list(y2019)
remove = "CODE"

geolist2 = [i for i in geolist if i not in remove]

geolist2

if not remove=="":
    #display(y2019.drop(columns=remove))
# Out:
#   File "<ipython-input-128-1b778c069b0d>", line 9
#     #display(y2019.drop(columns=remove))
#                                         ^
# SyntaxError: unexpected EOF while parsing

# %%
distrib_plot_v2(y2019d,y2018d,'CODE', difference=False, normalized = True, placement='series', universe="PFTOT",
                sample_size = 2)
# Out:
#         CODE variable  value Flag  normalized
# 0   35204005   PF0004     40  new    4.550626
# 2   35204005   PF0509     35  new    3.981797
# 4   35204005   PF1014     35  new    3.981797
# 6   35204005   PF1519     26  new    2.957907
# 8   35204005   PF2024     49  new    5.574516
# 10  35204005   PF2529     53  new    6.029579
# 12  35204005   PF3034     44  new    5.005688
# 14  35204005   PF3539     44  new    5.005688
# 16  35204005   PF4044     57  new    6.484642
# 18  35204005   PF4549     62  new    7.053470
# 20  35204005   PF5054     65  new    7.394767
# 22  35204005   PF5559     70  new    7.963595
# 24  35204005   PF6064     71  new    8.077361
# 26  35204005   PF6569     65  new    7.394767
# 28  35204005   PF7074     53  new    6.029579
# 30  35204005   PF7579     36  new    4.095563
# 32  35204005   PF8084     34  new    3.868032
# 34  35204005    PF85P     40  new    4.550626
# 36  35204005   PF0004     40  old    4.555809
# 38  35204005   PF0509     35  old    3.986333
# 40  35204005   PF1014     35  old    3.986333
# 42  35204005   PF1519     28  old    3.189066
# 44  35204005   PF2024     51  old    5.808656
# 46  35204005   PF2529     47  old    5.353075
# 48  35204005   PF3034     41  old    4.669704
# 50  35204005   PF3539     45  old    5.125285
# 52  35204005   PF4044     61  old    6.947608
# 54  35204005   PF4549     63  old    7.175399
# 56  35204005   PF5054     66  old    7.517084
# 58  35204005   PF5559     69  old    7.858770
# 60  35204005   PF6064     71  old    8.086560
# 62  35204005   PF6569     63  old    7.175399
# 64  35204005   PF7074     50  old    5.694761
# 66  35204005   PF7579     37  old    4.214123
# 68  35204005   PF8084     34  old    3.872437
# 70  35204005    PF85P     42  old    4.783599
#         CODE variable  value Flag  normalized
# 1   35300480   PF0004     13  new    4.529617
# 3   35300480   PF0509     19  new    6.620209
# 5   35300480   PF1014     10  new    3.484321
# 7   35300480   PF1519     18  new    6.271777
# 9   35300480   PF2024     16  new    5.574913
# 11  35300480   PF2529     16  new    5.574913
# 13  35300480   PF3034     14  new    4.878049
# 15  35300480   PF3539     16  new    5.574913
# 17  35300480   PF4044     11  new    3.832753
# 19  35300480   PF4549     21  new    7.317073
# 21  35300480   PF5054     30  new   10.452962
# 23  35300480   PF5559     24  new    8.362369
# 25  35300480   PF6064     24  new    8.362369
# 27  35300480   PF6569     14  new    4.878049
# 29  35300480   PF7074     15  new    5.226481
# 31  35300480   PF7579     11  new    3.832753
# 33  35300480   PF8084     10  new    3.484321
# 35  35300480    PF85P      5  new    1.742160
# 37  35300480   PF0004     13  old    4.498270
# 39  35300480   PF0509     19  old    6.574394
# 41  35300480   PF1014     10  old    3.460208
# 43  35300480   PF1519     19  old    6.574394
# 45  35300480   PF2024     16  old    5.536332
# 47  35300480   PF2529     16  old    5.536332
# 49  35300480   PF3034     14  old    4.844291
# 51  35300480   PF3539     16  old    5.536332
# 53  35300480   PF4044     11  old    3.806228
# 55  35300480   PF4549     21  old    7.266436
# 57  35300480   PF5054     31  old   10.726644
# 59  35300480   PF5559     24  old    8.304498
# 61  35300480   PF6064     24  old    8.304498
# 63  35300480   PF6569     14  old    4.844291
# 65  35300480   PF7074     15  old    5.190311
# 67  35300480   PF7579     11  old    3.806228
# 69  35300480   PF8084     10  old    3.460208
# 71  35300480    PF85P      5  old    1.730104

# %%
for i in range(len(sub_set)):
    for x in range(len(sub_set[i])):
        print(sub_set[i][x])
# Out:
# 35210189
# 48140061
# 48060416
# 35140191
# 35070169
# 35260494
# 24662706
# 35060308
# 46110382
# 48010188

# %%
#facetted vs grouped bar plot
combined = y2019d.merge(y2018d, how='inner', left_on='CODE', right_on='CODE',suffixes=("_x","_y"))
combined['CODE'] = combined['CODE'].astype(str)
        
            
  
        
Geo_list = list(combined.CODE)
sub_set=[i for i in random.sample(Geo_list,1)]
final_df = combined[combined['CODE'].isin(sub_set)]
sub_set.sort()
#print(sub_set)
#final_df
final_df_t = pd.melt(final_df,id_vars=['CODE'])
#print(final_df_t)

final_df_t['Flag']= final_df_t['variable'].apply(lambda x: x.split("_")[1])
final_df_t['variable']= final_df_t['variable'].apply(lambda x: x.split("_")[0]) 
print(final_df_t)


# groupedvalues=final_df_t.groupby(['Flag','variable']).sum().reset_index()

# #f,ax = plt.subplots(figsize=(15,6)) - does not work figsize controlled by a different level

# g = sns.FacetGrid(final_df_t, row = "Flag", size=10, aspect=1.3)
# g.map(sns.barplot, "variable", "value")


# # for index, row in groupedvalues.iterrows():
# #     #print(index,row)
# #     g.text(row.variable[row],row.value[row], round(row.total_bill,2), color='black', ha="center")


plt.figure(figsize=(15,16)) 

g = sns.pointplot(x="variable", y="value", hue="Flag", data=final_df_t,
                height=10, kind="bar", palette="muted", aspect =1.3)


ax = plt.gca()

for p in zip(ax.get_xticks(), final_df_t.value):
    print(p)
for a in list(final_df_t.Flag):
    [ax.text(p[0], p[1]-4, p[1]) for p in zip(ax.get_xticks(), final_df_t[final_df_t['Flag']==a].value)]
#[ax.text(p[0], p[1]+4, p[1]) for p in zip(ax.get_xticks(), final_df_t[final_df_t['Flag']=='y'].value)]

# for p in ax.patches:
#     ax.text(p.get_x() + p.get_width()/2., p.get_height(), '%d' % int(p.get_height()), 
#             fontsize=10, color='black', ha='center', va='bottom')

plt.show()


# for index, row in groupedvalues.iterrows():
#     g.axes[0].text(row.variable,row.value, color='black', ha="center")



#g.axes[0].text(...)

#sns.barplot(x='variable',y='value', data=final_df_t[final_df_t['Flag']=='y'])
#sns.barplot(x='variable',y='value', data=final_df_t[final_df_t['Flag']=='x'])
# Out:
#         CODE variable  value Flag
# 0   35300403    PFTOT    280    x
# 1   35300403   PF0004     12    x
# 2   35300403   PF0509     14    x
# 3   35300403   PF1014     15    x
# 4   35300403   PF1519     14    x
# 5   35300403   PF2024     11    x
# 6   35300403   PF2529     13    x
# 7   35300403   PF3034     19    x
# 8   35300403   PF3539     19    x
# 9   35300403   PF4044     20    x
# 10  35300403   PF4549     17    x
# 11  35300403   PF5054     17    x
# 12  35300403   PF5559     21    x
# 13  35300403   PF6064     18    x
# 14  35300403   PF6569     18    x
# 15  35300403   PF7074     15    x
# 16  35300403   PF7579     18    x
# 17  35300403   PF8084     13    x
# 18  35300403    PF85P      6    x
# 19  35300403    PFTOT    280    y
# 20  35300403   PF0004     11    y
# 21  35300403   PF0509     15    y
# 22  35300403   PF1014     16    y
# 23  35300403   PF1519     14    y
# 24  35300403   PF2024     11    y
# 25  35300403   PF2529     14    y
# 26  35300403   PF3034     20    y
# 27  35300403   PF3539     19    y
# 28  35300403   PF4044     21    y
# 29  35300403   PF4549     17    y
# 30  35300403   PF5054     17    y
# 31  35300403   PF5559     21    y
# 32  35300403   PF6064     17    y
# 33  35300403   PF6569     18    y
# 34  35300403   PF7074     15    y
# 35  35300403   PF7579     18    y
# 36  35300403   PF8084     12    y
# 37  35300403    PF85P      4    y
# (0, 280)
# (1, 12)
# (2, 14)
# (3, 15)
# (4, 14)
# (5, 11)
# (6, 13)
# (7, 19)
# (8, 19)
# (9, 20)
# (10, 17)
# (11, 17)
# (12, 21)
# (13, 18)
# (14, 18)
# (15, 15)
# (16, 18)
# (17, 13)
# (18, 6)

# %%
tested = zip(list(y2019), list(y2018))

# %%
tested2 = [list(i) for i in tested]

# %%
tested2 = tested2[1:]

# %%
tested2
# Out:
# [['AITOT', 'AITOT'], ['AIABOR', 'AIABOR'], ['AINABOR', 'AINABOR']]

# %%
#difference

vars = list(y2019d)
vars.remove("CODE")
vars
# Out:
# ['PFTOT',
#  'PF0004',
#  'PF0509',
#  'PF1014',
#  'PF1519',
#  'PF2024',
#  'PF2529',
#  'PF3034',
#  'PF3539',
#  'PF4044',
#  'PF4549',
#  'PF5054',
#  'PF5559',
#  'PF6064',
#  'PF6569',
#  'PF7074',
#  'PF7579',
#  'PF8084',
#  'PF85P']

# %%
df_diff = pd.DataFrame(y2019d["CODE"])

for var in vars:
    df_diff["diff_"+var] = y2019d[var]-y2018d[var]

df_diff.dropna(inplace = True )
df_diff['CODE'] = df_diff['CODE'].astype(str)

# %%
Geo_list = list(combined.CODE)
sub_set=[i for i in random.sample(Geo_list,1)]
final_df = df_diff[df_diff['CODE'].isin(sub_set)]
sub_set.sort()
print(sub_set)
final_df_t = pd.melt(final_df,id_vars=['CODE'])
final_df_t

g = sns.catplot(x="variable", y="value", data=final_df_t,
                height=10, kind="bar", palette="muted", aspect =1.3)

g.set_xticklabels(rotation=30)

ax = plt.gca()

for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2., p.get_height(), '%d' % int(p.get_height()), 
            fontsize=10, color='black', ha='center', va='bottom')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-147-c721e45af7e3> in <module>
# ----> 1 Geo_list = list(combined.CODE)
#       2 sub_set=[i for i in random.sample(Geo_list,1)]
#       3 final_df = df_diff[df_diff['CODE'].isin(sub_set)]
#       4 sub_set.sort()
#       5 print(sub_set)
#
# NameError: name 'combined' is not defined

# %%
#normalized

  
        
Geo_list = list(combined.CODE)
sub_set=[i for i in random.sample(Geo_list,1)]
final_df = combined[combined['CODE'].isin(sub_set)]
sub_set.sort()
print(sub_set)
#final_df
final_df_t = pd.melt(final_df,id_vars=['CODE'])


final_df_t['Flag']= final_df_t['variable'].apply(lambda x: x[-1:])
final_df_t['variable']= final_df_t['variable'].apply(lambda x: x[:-2]) 
final_df_t
# Out:
# ['24230316']
#         CODE variable  value Flag
# 0   24230316    PFTOT    266    x
# 1   24230316   PF0004     12    x
# 2   24230316   PF0509      6    x
# 3   24230316   PF1014      9    x
# 4   24230316   PF1519     10    x
# 5   24230316   PF2024     11    x
# 6   24230316   PF2529     24    x
# 7   24230316   PF3034     13    x
# 8   24230316   PF3539     11    x
# 9   24230316   PF4044     17    x
# 10  24230316   PF4549     16    x
# 11  24230316   PF5054      7    x
# 12  24230316   PF5559     15    x
# 13  24230316   PF6064     11    x
# 14  24230316   PF6569     18    x
# 15  24230316   PF7074     14    x
# 16  24230316   PF7579     12    x
# 17  24230316   PF8084     15    x
# 18  24230316    PF85P     45    x
# 19  24230316    PFTOT    264    y
# 20  24230316   PF0004     12    y
# 21  24230316   PF0509      6    y
# 22  24230316   PF1014      8    y
# 23  24230316   PF1519     10    y
# 24  24230316   PF2024     11    y
# 25  24230316   PF2529     24    y
# 26  24230316   PF3034     13    y
# 27  24230316   PF3539     11    y
# 28  24230316   PF4044     16    y
# 29  24230316   PF4549     15    y
# 30  24230316   PF5054      7    y
# 31  24230316   PF5559     15    y
# 32  24230316   PF6064     11    y
# 33  24230316   PF6569     18    y
# 34  24230316   PF7074     14    y
# 35  24230316   PF7579     12    y
# 36  24230316   PF8084     15    y
# 37  24230316    PF85P     46    y

# %%
#final_df_t
final_df_t = final_df_t.assign(normalized=final_df_t.value.div(final_df_t.Flag.map(final_df_t.groupby('Flag').value.sum()))*100)
final_df_t


g = sns.catplot(x="variable", y="normalized", hue="Flag", data=final_df_t,
                height=10, kind="bar", palette="muted", aspect =1.3)


ax = plt.gca()

for p in ax.patches:
     ax.annotate(round(p.get_height(),3), (p.get_x() * 1.005, p.get_height() * 1.005), rotation=90 )

g.set_titles(row_template="{row_name}", col_template="{col_name}",size = 15)
    
#     ax.text(p.get_x() + p.get_width()/2., p.get_height(), '%d' % p.get_height(), 
#             fontsize=10, color='black', ha='center', va='bottom')
#     print(p.get_height())

# %%
test = 'PF1014__new'

# %%
# Out:
# ['PF1014', '', 'new']

# %% [markdown]
# ## Function 3

# %%
def box_n_hist(lists,df_new,df_old,join_field, new_suf='_new', old_suf='_old', show_outliers=True):
    test=1
    try:
        var1 = lists[0]
        
    except:
        test=0
        print('we out')
        return False
    
    try:
        var2 = lists[0][1]
        
    except:
        test=0
        print('we out still')
        
    else:
        
        combined = df_new.merge(df_old, how='inner', left_on='{}'.format(join_field), right_on='{}'.format(join_field), suffixes=("{}".format(new_suf),"{}".format(old_suf)))
        return combined
            
    finally:
          
        
        for pairs in range(len(lists)):
            x = lists[pairs][0]+"_x"
            y = lists[pairs][1]+"_y"
            final_df = combined[[join_field,x,y]]
            final_df_t = final_df.melt(id_vars=[join_field])
            print(final_df_t)
            
            f,ax = plt.subplots(figsize=(15,6))
            sns.boxplot(x='variable', y='value', data = final_df_t, showfliers= show_outliers, ax=ax)#, ax=ax[pairs][1])
            
            g = sns.FacetGrid(final_df_t, hue="variable", height=10, aspect=1.3)
#             g.map(plt.hist, "value", histtype='barstacked', stacked=True);
#             plt.legend();
            
            g.map(sns.distplot, "value")
            plt.legend();
            
#             sns.distplot(final_df[x])
#             sns.distplot(final_df[y])
        
            plt.show()
           
            #sns.boxplot(x=y, data = combined, ax=ax)
            #sns.regplot(x=x,y=y,data = combined,scatter_kws={'alpha':0.03})
            #set title
            #print("\n\n")
           # plt.suptitle('Scatter of {} vs {}'.format(x,y),fontsize=18, ha='center')
            #plt.title('R-Squared: {}, P-value: {}'.format(r2, r2a),ha='center')
           # plt.show()

# %%
def box_n_hist_v2(lists,df_new,df_old,join_field, show_outliers=False):
    test=1
    try:
        var1 = lists[0]
        
    except:
        test=0
        print('we out')
        return False
    
    try:
        var2 = lists[0][1]
        
    except:
        test=0
        print('we out still')
        
    else:
        
        combined = df_new.merge(df_old, how='inner', left_on='{}'.format(join_field), right_on='{}'.format(join_field), suffixes=("_new","_old"))
        
            
    finally:
          
        display(combined)
        
        for pairs in range(len(lists)):
            x = lists[pairs]+"_new"
            y = lists[pairs]+"_old"
            final_df = combined[[join_field,x,y]]
            final_df_t = final_df.melt(id_vars=[join_field])
            #print(final_df_t)
            
            f,ax = plt.subplots(figsize=(15,6))
            sns.boxplot(x='variable', y='value', data = final_df_t, showfliers= show_outliers, ax=ax)#, ax=ax[pairs][1])
            
            plt.title('Boxplost of {} and {}'.format(x, y),ha='center')
            
            g = sns.FacetGrid(final_df_t, hue="variable", height=10, aspect=1.3)
#             g.map(plt.hist, "value", histtype='barstacked', stacked=True);
#             plt.legend();
            
            g.map(sns.distplot, "value")
        
            plt.title('Histograms of {} and {}'.format(x, y),ha='center')
            plt.legend();
            
#             sns.distplot(final_df[x])
#             sns.distplot(final_df[y])
        
            plt.show()
           
            #sns.boxplot(x=y, data = combined, ax=ax)
            #sns.regplot(x=x,y=y,data = combined,scatter_kws={'alpha':0.03})
            #set title
            #print("\n\n")
           # plt.suptitle('Scatter of {} vs {}'.format(x,y),fontsize=18, ha='center')
            #plt.title('R-Squared: {}, P-value: {}'.format(r2, r2a),ha='center')
           # plt.show()

# %%
inputtest = list(y2019)
inputtest.remove('CODE')
inputtest

box_n_hist_v2(inputtest,y2019,y2018,'CODE')
# Out:
#            CODE  AITOT_new  AIABOR_new  AINABOR_new  AITOT_old  AIABOR_old  \
# 0      10010165        515          19          496        567          30
# 1      10010166        328           0          328        327          12
# 2      10010167        442          41          401        447           5
# 3      10010168        531          11          520        550          20
# 4      10010169        317           0          317        315           7
# 5      10010170        403          28          375        396          23
# 6      10010171        489          14          475        488          11
# 7      10010172        228           2          226        226           8
# 8      10010173        907           9          898        904          19
# 9      10010174        883          58          825        913          86
# 10     10010175        979          46          933       1014           6
# 11     10010176        433          11          422        440           7
# 12     10010180        542           9          533        697          19
# 13     10010181        376           0          376        373           0
# 14     10010182        371          26          345        366          10
# 15     10010187        679          64          615        692           2
# 16     10010191        659           3          656        780           1
# 17     10010192        292          20          272        319          10
# 18     10010193        464           1          463        492          45
# 19     10010194        224          19          205        252           7
# 20     10010195        851          17          834        692           2
# 21     10010196        522          17          505        548          13
# 22     10010198        441           9          432        436           6
# 23     10010199        243           4          239        219           1
# 24     10010200        418           4          414        429           5
# 25     10010201        471          17          454        493           4
# 26     10010202        448           9          439        462           3
# 27     10010203        338           6          332        361           9
# 28     10010204        553           2          551        591          14
# 29     10010206        920          61          859        846           6
# ...         ...        ...         ...          ...        ...         ...
# 56560  62040068       1016         939           77        961         923
# 56561  62040069       1210        1138           72       1128        1075
# 56562  62040070        686         656           30        629         609
# 56563  62040071        804         771           33        785         701
# 56564  62040072        337         337            0        334         288
# 56565  62050012       1173        1129           44       1137        1110
# 56566  62050013          0           0            0          0           0
# 56567  62050014        483         460           23        443         391
# 56568  62050015        943         906           37        933         892
# 56569  62050017        452         430           22        459         449
# 56570  62050020       1714        1402          312       1527        1262
# 56571  62050021       1267        1081          186       1416        1122
# 56572  62050022        951         839          112        942         868
# 56573  62050023        731         715           16        722         662
# 56574  62050024        509         478           31        501         467
# 56575  62050025       1510        1456           54       1491        1415
# 56576  62050026        604         548           56        518         482
# 56577  62050027        741         721           20        786         753
# 56578  62080015          0           0            0          0           0
# 56579  62080017       1156        1110           46       1094        1028
# 56580  62080018       1042        1002           40       1017         970
# 56581  62080020          0           0            0          0           0
# 56582  62080021          5           5            0          5           2
# 56583  62080022        785         523          262        766         574
# 56584  62080023        643         559           84        615         504
# 56585  62080024        495         359          136        486         365
# 56586  62080025        574         517           57        567         456
# 56587  62080026       1049         946          103       1019         912
# 56588  62080027        854         813           41        816         764
# 56589  62080028        563         555            8        566         561
#
#        AINABOR_old
# 0              537
# 1              315
# 2              442
# 3              530
# 4              308
# 5              373
# 6              477
# 7              218
# 8              885
# 9              827
# 10            1008
# 11             433
# 12             678
# 13             373
# 14             356
# 15             690
# 16             779
# 17             309
# 18             447
# 19             245
# 20             690
# 21             535
# 22             430
# 23             218
# 24             424
# 25             489
# 26             459
# 27             352
# 28             577
# 29             840
# ...            ...
# 56560           38
# 56561           53
# 56562           20
# 56563           84
# 56564           46
# 56565           27
# 56566            0
# 56567           52
# 56568           41
# 56569           10
# 56570          265
# 56571          294
# 56572           74
# 56573           60
# 56574           34
# 56575           76
# 56576           36
# 56577           33
# 56578            0
# 56579           66
# 56580           47
# 56581            0
# 56582            3
# 56583          192
# 56584          111
# 56585          121
# 56586          111
# 56587          107
# 56588           52
# 56589            5
#
# [56590 rows x 7 columns]

# %%
test_list = list(y2019)

for item in test_list:
    sns.distplot(y2019[item])
    plt.show()

# %% [markdown]
# ## Function 4

# %%
import copy

df4_orig = df4_func4.copy()

df4_func4.loc[df4_func4["Flag"]=="new", "Flag"]="2019"
df4_func4.loc[df4_func4["Flag"]=="old", "Flag"]="2018"

# %%
df4_func4.Flag = df4_func4.Flag.astype(int)                                    )
# Out:
#   File "<ipython-input-146-5b473aefde53>", line 1
#     df4_func4.Flag = df4_func4.Flag.astype(int)                                    )
#                                                                                    ^
# SyntaxError: invalid syntax

# %%
df4_func4.Flag.dtype == int
df4_orig.Flag.dtype == object
# Out:
# True

# %%
if placement == "grouped":

                    g = sns.catplot(x="variable", y="normalized", hue="Flag", data=final_df_t,
                                height=10, kind="bar", palette="muted", aspect =1.3)

                    ax = plt.gca()

                    for p in ax.patches:
                        for p in ax.patches:
                             ax.annotate(round(p.get_height(),3), (p.get_x() * 1.005, p.get_height() * 1.005), rotation=90 )
elif placement == "series":
                    plt.figure(figsize=(15,16)) 

                    g = sns.pointplot(x="variable", y="normalized", hue="Flag", data=final_df_t,
                                    height=10, kind="bar", palette="muted", aspect =1.3)

# %%
plt.figure(figsize=(15,16)) 

sns.pointplot(x="Flag", y="value", data=df4_func4, kind="bar",
                 height=10, aspect=.7);

# %%
plt.figure(figsize=(15,16)) 
    
sns.lineplot(x="variable", y="value",hue="Flag", data=df4_func4)

# %%
sns.pointplot(data=df4_func4)

# %%
ws_df = pd.read_csv("wsct_years.csv")
ws_df.Year = ws_df.Year.astype(str) 
ws_df.head()
# Out:
#                                   Control  Region    Stream    Year  \
# 0  Investment Products - Short Term Paper  Canada  Interest  2003.0
# 1  Investment Products - Short Term Paper  Canada  Interest  2004.0
# 2  Investment Products - Short Term Paper  Canada  Interest  2005.0
# 3  Investment Products - Short Term Paper  Canada  Interest  2006.0
# 4  Investment Products - Short Term Paper  Canada  Interest  2007.0
#
#           Value                                             Source Notes
# 0  5.218000e+09  Statistics Canada, National Balance Sheet (acc...   NaN
# 1  3.416000e+09  Statistics Canada, National Balance Sheet (acc...   NaN
# 2  2.382000e+09  Statistics Canada, National Balance Sheet (acc...   NaN
# 3  4.821000e+09  Statistics Canada, National Balance Sheet (acc...   NaN
# 4  4.998000e+09  Statistics Canada, National Balance Sheet (acc...   NaN

# %%
plt.figure(figsize=(15,16)) 
    
sns.lineplot(x="Year", y="Value",hue="Control", data=ws_df, legend =False)

# %%
ws_df2 = pd.read_csv("wsct_subset.csv")
ws_df2.Year = ws_df2.Year.astype(str)

#ws_df2.groupby(["Control"]).size()
ws_df2.Control.dtype
# Out:
# dtype('O')

# %%
ws_df2[ws_df2["Control"]=="Investment Products - Mortgages Held"]
# Out:
#                                  Control  Region    Stream  Year  \
# 30  Investment Products - Mortgages Held  Canada  Interest  2003
# 31  Investment Products - Mortgages Held  Canada  Interest  2004
# 32  Investment Products - Mortgages Held  Canada  Interest  2005
# 33  Investment Products - Mortgages Held  Canada  Interest  2006
# 34  Investment Products - Mortgages Held  Canada  Interest  2007
# 35  Investment Products - Mortgages Held  Canada  Interest  2008
# 36  Investment Products - Mortgages Held  Canada  Interest  2009
# 37  Investment Products - Mortgages Held  Canada  Interest  2010
# 38  Investment Products - Mortgages Held  Canada  Interest  2011
# 39  Investment Products - Mortgages Held  Canada  Interest  2012
# 40  Investment Products - Mortgages Held  Canada  Interest  2013
# 41  Investment Products - Mortgages Held  Canada  Interest  2014
# 42  Investment Products - Mortgages Held  Canada  Interest  2015
# 43  Investment Products - Mortgages Held  Canada  Interest  2016
# 44  Investment Products - Mortgages Held  Canada  Interest  2017
#
#            Value                                             Source Notes
# 30  6.953000e+09  Statistics Canada, National Balance Sheet (acc...   NaN
# 31  6.559000e+09  Statistics Canada, National Balance Sheet (acc...   NaN
# 32  6.924000e+09  Statistics Canada, National Balance Sheet (acc...   NaN
# 33  7.234000e+09  Statistics Canada, National Balance Sheet (acc...   NaN
# 34  8.496000e+09  Statistics Canada, National Balance Sheet (acc...   NaN
# 35  7.319000e+09  Statistics Canada, National Balance Sheet (acc...   NaN
# 36  5.485000e+09  Statistics Canada, National Balance Sheet (acc...   NaN
# 37  5.260000e+09  Statistics Canada, National Balance Sheet (acc...   NaN
# 38  5.260000e+09  Statistics Canada, National Balance Sheet (acc...   NaN
# 39  5.032000e+09  Statistics Canada, National Balance Sheet (acc...   NaN
# 40  5.218000e+09  Statistics Canada, National Balance Sheet (acc...   NaN
# 41  4.622000e+09  Statistics Canada, National Balance Sheet (acc...   NaN
# 42  4.501000e+09  Statistics Canada, National Balance Sheet (acc...   NaN
# 43  4.491000e+09  Statistics Canada, National Balance Sheet (acc...   NaN
# 44  4.867000e+09  Statistics Canada, National Balance Sheet (acc...   NaN

# %%
import numpy as np
ws_df2

# %%
#abs diff
ws_df2["abs_diff"]= ws_df2.groupby("Control")["Value"].apply(lambda x: x.diff())
#percent diff
ws_df2["pct_diff"]= ws_df2.groupby("Control")["Value"].apply(lambda x: x.diff()/x)


#cumulative sum function by group
ws_df2["cumulative"] = ws_df2.groupby("Control")["Value"].cumsum()


#create interval labels
ws_df2["intervals"]=ws_df2.groupby("Control")["Year"].transform(lambda x: x.shift(1) + "-" + x)


#drop beginning intevals where
ws_df2[~(ws_df2["intervals"].isna())]
# Out:
#                                               Control  Region    Stream  Year  \
# 1              Investment Products - Short Term Paper  Canada  Interest  2004
# 2              Investment Products - Short Term Paper  Canada  Interest  2005
# 3              Investment Products - Short Term Paper  Canada  Interest  2006
# 4              Investment Products - Short Term Paper  Canada  Interest  2007
# 5              Investment Products - Short Term Paper  Canada  Interest  2008
# 6              Investment Products - Short Term Paper  Canada  Interest  2009
# 7              Investment Products - Short Term Paper  Canada  Interest  2010
# 8              Investment Products - Short Term Paper  Canada  Interest  2011
# 9              Investment Products - Short Term Paper  Canada  Interest  2012
# 10             Investment Products - Short Term Paper  Canada  Interest  2013
# 11             Investment Products - Short Term Paper  Canada  Interest  2014
# 12             Investment Products - Short Term Paper  Canada  Interest  2015
# 13             Investment Products - Short Term Paper  Canada  Interest  2016
# 14             Investment Products - Short Term Paper  Canada  Interest  2017
# 16         Investment Products - Canada Savings Bonds  Canada  Interest  2004
# 17         Investment Products - Canada Savings Bonds  Canada  Interest  2005
# 18         Investment Products - Canada Savings Bonds  Canada  Interest  2006
# 19         Investment Products - Canada Savings Bonds  Canada  Interest  2007
# 20         Investment Products - Canada Savings Bonds  Canada  Interest  2008
# 21         Investment Products - Canada Savings Bonds  Canada  Interest  2009
# 22         Investment Products - Canada Savings Bonds  Canada  Interest  2010
# 23         Investment Products - Canada Savings Bonds  Canada  Interest  2011
# 24         Investment Products - Canada Savings Bonds  Canada  Interest  2012
# 25         Investment Products - Canada Savings Bonds  Canada  Interest  2013
# 26         Investment Products - Canada Savings Bonds  Canada  Interest  2014
# 27         Investment Products - Canada Savings Bonds  Canada  Interest  2015
# 28         Investment Products - Canada Savings Bonds  Canada  Interest  2016
# 29         Investment Products - Canada Savings Bonds  Canada  Interest  2017
# 31               Investment Products - Mortgages Held  Canada  Interest  2004
# 32               Investment Products - Mortgages Held  Canada  Interest  2005
# ..                                                ...     ...       ...   ...
# 52  Investment Products - Segregated Funds - Divid...  Canada  Dividend  2008
# 53  Investment Products - Investment Funds - Divid...  Canada  Dividend  2005
# 54  Investment Products - Investment Funds - Divid...  Canada  Dividend  2006
# 55  Investment Products - Investment Funds - Divid...  Canada  Dividend  2007
# 56  Investment Products - Investment Funds - Divid...  Canada  Dividend  2008
# 57  Investment Products - Investment Funds - Divid...  Canada  Dividend  2009
# 58  Investment Products - Investment Funds - Divid...  Canada  Dividend  2010
# 59  Investment Products - Investment Funds - Divid...  Canada  Dividend  2011
# 60  Investment Products - Investment Funds - Divid...  Canada  Dividend  2012
# 61  Investment Products - Investment Funds - Divid...  Canada  Dividend  2013
# 62  Investment Products - Investment Funds - Divid...  Canada  Dividend  2014
# 63  Investment Products - Investment Funds - Divid...  Canada  Dividend  2015
# 64  Investment Products - Investment Funds - Divid...  Canada  Dividend  2016
# 65  Investment Products - Investment Funds - Divid...  Canada  Dividend  2017
# 66  Investment Products - Segregated Funds - Divid...  Canada  Dividend  2009
# 67  Investment Products - Segregated Funds - Divid...  Canada  Dividend  2010
# 68  Investment Products - Segregated Funds - Divid...  Canada  Dividend  2011
# 69  Investment Products - Segregated Funds - Divid...  Canada  Dividend  2012
# 71  Investment Products - Investment Funds - Inter...  Canada  Interest  2004
# 72  Investment Products - Investment Funds - Inter...  Canada  Interest  2005
# 73  Investment Products - Investment Funds - Inter...  Canada  Interest  2006
# 74  Investment Products - Investment Funds - Inter...  Canada  Interest  2007
# 75  Investment Products - Investment Funds - Inter...  Canada  Interest  2008
# 76  Investment Products - Investment Funds - Inter...  Canada  Interest  2009
# 77  Investment Products - Investment Funds - Inter...  Canada  Interest  2010
# 78  Investment Products - Investment Funds - Inter...  Canada  Interest  2011
# 79  Investment Products - Investment Funds - Inter...  Canada  Interest  2012
# 80  Investment Products - Investment Funds - Inter...  Canada  Interest  2013
# 81  Investment Products - Investment Funds - Inter...  Canada  Interest  2014
# 82  Investment Products - Investment Funds - Inter...  Canada  Interest  2015
#
#            Value                                             Source  \
# 1   3.416000e+09  Statistics Canada, National Balance Sheet (acc...
# 2   2.382000e+09  Statistics Canada, National Balance Sheet (acc...
# 3   4.821000e+09  Statistics Canada, National Balance Sheet (acc...
# 4   4.998000e+09  Statistics Canada, National Balance Sheet (acc...
# 5   7.543000e+09  Statistics Canada, National Balance Sheet (acc...
# 6   5.949000e+09  Statistics Canada, National Balance Sheet (acc...
# 7   4.420000e+09  Statistics Canada, National Balance Sheet (acc...
# 8   4.464000e+09  Statistics Canada, National Balance Sheet (acc...
# 9   4.839000e+09  Statistics Canada, National Balance Sheet (acc...
# 10  4.930000e+09  Statistics Canada, National Balance Sheet (acc...
# 11  5.076000e+09  Statistics Canada, National Balance Sheet (acc...
# 12  6.202000e+09  Statistics Canada, National Balance Sheet (acc...
# 13  5.686000e+09  Statistics Canada, National Balance Sheet (acc...
# 14  6.030000e+09  Statistics Canada, National Balance Sheet (acc...
# 16  2.033400e+10  Bank of Canada Banking and Financial Statistic...
# 17  1.791300e+10  Bank of Canada Banking and Financial Statistic...
# 18  1.556000e+10  Bank of Canada Banking and Financial Statistic...
# 19  1.303300e+10  Bank of Canada Banking and Financial Statistic...
# 20  1.222500e+10  Bank of Canada Banking and Financial Statistic...
# 21  1.218800e+10  Bank of Canada Banking and Financial Statistic...
# 22  1.075800e+10  Bank of Canada Banking and Financial Statistic...
# 23  9.453000e+09  Bank of Canada Banking and Financial Statistic...
# 24  8.157000e+09  Bank of Canada Banking and Financial Statistic...
# 25  6.972000e+09  Bank of Canada Banking and Financial Statistic...
# 26  6.159000e+09  Bank of Canada Banking and Financial Statistic...
# 27  5.593000e+09  Bank of Canada Banking and Financial Statistic...
# 28  5.149000e+09  Bank of Canada Banking and Financial Statistic...
# 29  3.504000e+09  Bank of Canada Banking and Financial Statistic...
# 31  6.559000e+09  Statistics Canada, National Balance Sheet (acc...
# 32  6.924000e+09  Statistics Canada, National Balance Sheet (acc...
# ..           ...                                                ...
# 52  6.305171e+10                                                NaN
# 53  3.570000e+11  Statistics Canada, National Balance Sheet (acc...
# 54  4.250000e+11  Statistics Canada, National Balance Sheet (acc...
# 55  4.580000e+11  Statistics Canada, National Balance Sheet (acc...
# 56  3.190000e+11  Statistics Canada, National Balance Sheet (acc...
# 57  4.070000e+11  Statistics Canada, National Balance Sheet (acc...
# 58  4.570000e+11  Statistics Canada, National Balance Sheet (acc...
# 59  4.340000e+11  Statistics Canada, National Balance Sheet (acc...
# 60  4.850000e+11  Statistics Canada, National Balance Sheet (acc...
# 61  5.890000e+11  Statistics Canada, National Balance Sheet (acc...
# 62  6.900000e+11  Statistics Canada, National Balance Sheet (acc...
# 63  7.520000e+11  Statistics Canada, National Balance Sheet (acc...
# 64  8.380000e+11  Statistics Canada, National Balance Sheet (acc...
# 65  9.710000e+11  Statistics Canada, National Balance Sheet (acc...
# 66  8.414911e+10                                                NaN
# 67  9.169764e+10                                                NaN
# 68  9.357493e+10                                                NaN
# 69  1.060000e+11                                                NaN
# 71  1.470000e+11  Statistics Canada, National Balance Sheet (acc...
# 72  1.670000e+11  Statistics Canada, National Balance Sheet (acc...
# 73  1.780000e+11  Statistics Canada, National Balance Sheet (acc...
# 74  1.850000e+11  Statistics Canada, National Balance Sheet (acc...
# 75  2.040000e+11  Statistics Canada, National Balance Sheet (acc...
# 76  2.010000e+11  Statistics Canada, National Balance Sheet (acc...
# 77  2.030000e+11  Statistics Canada, National Balance Sheet (acc...
# 78  2.330000e+11  Statistics Canada, National Balance Sheet (acc...
# 79  2.610000e+11  Statistics Canada, National Balance Sheet (acc...
# 80  2.830000e+11  Statistics Canada, National Balance Sheet (acc...
# 81  3.230000e+11  Statistics Canada, National Balance Sheet (acc...
# 82  3.490000e+11  Statistics Canada, National Balance Sheet (acc...
#
#                                      Notes      abs_diff  pct_diff  \
# 1                                      NaN -1.802000e+09 -0.527518
# 2                                      NaN -1.034000e+09 -0.434089
# 3                                      NaN  2.439000e+09  0.505912
# 4                                      NaN  1.770000e+08  0.035414
# 5                                      NaN  2.545000e+09  0.337399
# 6                                      NaN -1.594000e+09 -0.267944
# 7                                      NaN -1.529000e+09 -0.345928
# 8                                      NaN  4.400000e+07  0.009857
# 9                                      NaN  3.750000e+08  0.077495
# 10                                     NaN  9.100000e+07  0.018458
# 11                                     NaN  1.460000e+08  0.028763
# 12                                     NaN  1.126000e+09  0.181554
# 13                                     NaN -5.160000e+08 -0.090749
# 14                                     NaN  3.440000e+08  0.057048
# 16                                     NaN -1.266000e+09 -0.062260
# 17                                     NaN -2.421000e+09 -0.135153
# 18                                     NaN -2.353000e+09 -0.151221
# 19                                     NaN -2.527000e+09 -0.193892
# 20                                     NaN -8.080000e+08 -0.066094
# 21                                     NaN -3.700000e+07 -0.003036
# 22                                     NaN -1.430000e+09 -0.132924
# 23                                     NaN -1.305000e+09 -0.138051
# 24                                     NaN -1.296000e+09 -0.158882
# 25                                     NaN -1.185000e+09 -0.169966
# 26                                     NaN -8.130000e+08 -0.132002
# 27                                     NaN -5.660000e+08 -0.101198
# 28                                     NaN -4.440000e+08 -0.086230
# 29                                     NaN -1.645000e+09 -0.469463
# 31                                     NaN -3.940000e+08 -0.060070
# 32                                     NaN  3.650000e+08  0.052715
# ..                                     ...           ...       ...
# 52  Now corrected to CLHIA control totals. -1.388512e+10 -0.220218
# 53                  BFS: $409,133,000,000.  6.800000e+10  0.190476
# 54                  BFS: $489,807,000,000.  6.800000e+10  0.160000
# 55                  BFS: $516,110,000,000.  3.300000e+10  0.072052
# 56                  BFS: $357,859,000,000. -1.390000e+11 -0.435737
# 57                  BFS: $455,184,000,000.  8.800000e+10  0.216216
# 58                  BFS: $522,324,000,000.  5.000000e+10  0.109409
# 59                  BFS: $495,228,000,000. -2.300000e+10 -0.052995
# 60                  BFS: $555,246,000,000.  5.100000e+10  0.105155
# 61                                     NaN  1.040000e+11  0.176570
# 62                                     NaN  1.010000e+11  0.146377
# 63                                     NaN  6.200000e+10  0.082447
# 64                                     NaN  8.600000e+10  0.102625
# 65                                     NaN  1.330000e+11  0.136972
# 66  Now corrected to CLHIA control totals.  2.109740e+10  0.250714
# 67  Now corrected to CLHIA control totals.  7.548530e+09  0.082320
# 68  Now corrected to CLHIA control totals.  1.877286e+09  0.020062
# 69  Now corrected to CLHIA control totals.  1.242507e+10  0.117218
# 71                  BFS: $165,885,000,000.  1.300000e+10  0.088435
# 72                  BFS: $180,092,000,000.  2.000000e+10  0.119760
# 73                  BFS: $193,403,000,000.  1.100000e+10  0.061798
# 74                  BFS: $205,561,000,000.  7.000000e+09  0.037838
# 75                  BFS: $211,211,000,000.  1.900000e+10  0.093137
# 76                  BFS: $208,488,000,000. -3.000000e+09 -0.014925
# 77                  BFS: $210,590,000,000.  2.000000e+09  0.009852
# 78                  BFS: $223,920,000,000.  3.000000e+10  0.128755
# 79                  BFS: $243,539,000,000.  2.800000e+10  0.107280
# 80                                     NaN  2.200000e+10  0.077739
# 81                                     NaN  4.000000e+10  0.123839
# 82                                     NaN  2.600000e+10  0.074499
#
#       cumulative  intervals
# 1   8.634000e+09  2003-2004
# 2   1.101600e+10  2004-2005
# 3   1.583700e+10  2005-2006
# 4   2.083500e+10  2006-2007
# 5   2.837800e+10  2007-2008
# 6   3.432700e+10  2008-2009
# 7   3.874700e+10  2009-2010
# 8   4.321100e+10  2010-2011
# 9   4.805000e+10  2011-2012
# 10  5.298000e+10  2012-2013
# 11  5.805600e+10  2013-2014
# 12  6.425800e+10  2014-2015
# 13  6.994400e+10  2015-2016
# 14  7.597400e+10  2016-2017
# 16  4.193400e+10  2003-2004
# 17  5.984700e+10  2004-2005
# 18  7.540700e+10  2005-2006
# 19  8.844000e+10  2006-2007
# 20  1.006650e+11  2007-2008
# 21  1.128530e+11  2008-2009
# 22  1.236110e+11  2009-2010
# 23  1.330640e+11  2010-2011
# 24  1.412210e+11  2011-2012
# 25  1.481930e+11  2012-2013
# 26  1.543520e+11  2013-2014
# 27  1.599450e+11  2014-2015
# 28  1.650940e+11  2015-2016
# 29  1.685980e+11  2016-2017
# 31  1.351200e+10  2003-2004
# 32  2.043600e+10  2004-2005
# ..           ...        ...
# 52  4.421754e+11  2007-2008
# 53  8.950000e+11  2004-2005
# 54  1.320000e+12  2005-2006
# 55  1.778000e+12  2006-2007
# 56  2.097000e+12  2007-2008
# 57  2.504000e+12  2008-2009
# 58  2.961000e+12  2009-2010
# 59  3.395000e+12  2010-2011
# 60  3.880000e+12  2011-2012
# 61  4.469000e+12  2012-2013
# 62  5.159000e+12  2013-2014
# 63  5.911000e+12  2014-2015
# 64  6.749000e+12  2015-2016
# 65  7.720000e+12  2016-2017
# 66  5.263245e+11  2008-2009
# 67  6.180221e+11  2009-2010
# 68  7.115971e+11  2010-2011
# 69  8.175971e+11  2011-2012
# 71  2.810000e+11  2003-2004
# 72  4.480000e+11  2004-2005
# 73  6.260000e+11  2005-2006
# 74  8.110000e+11  2006-2007
# 75  1.015000e+12  2007-2008
# 76  1.216000e+12  2008-2009
# 77  1.419000e+12  2009-2010
# 78  1.652000e+12  2010-2011
# 79  1.913000e+12  2011-2012
# 80  2.196000e+12  2012-2013
# 81  2.519000e+12  2013-2014
# 82  2.868000e+12  2014-2015
#
# [77 rows x 11 columns]

# %%
plt.figure(figsize=(15,16)) 
    
sns.catplot(x="Year", y="Value",hue="Control", data=ws_df2[ws_df2["Control"]=="Investment Products - Mortgages Held"], legend= "brief", kind="bar", height =15, aspect =1.3)

# %%
def one_df_distrib(df, x_axis, y_axis, series, normalized = True, placement="grouped", subset=None):
    
    if subset is not None:
        user_one = input ("Enter sample size number: ")
        sample_size = int(user_one)
        print("Sample size selected is: ", sample_size)
        
        user_two = input ("Enter field name for sampling (i.e. Geography field): ")
        subset_field = user_two
        print("Field selected is: ", subset_field)
        
        Geo_list = list(df.subset_field)
        sub_set=[i for i in random.sample(Geo_list,sample_size)]
        final_df = df[df[subset_field].isin(sub_set)]
        sub_set.sort()
        #print(sub_set)

        for s in sub_set:
            df = df[df[subset_field]==s]

    if df[x_axis].dtype == object:
        
        if normalized == True:
            
            df = df.assign(normalized = df[y_axis].div(df[series].map(df.groupby([series])[y_axis].sum())))
            display(df.head())
        
            if placement == 'grouped':

                g = sns.catplot(x=x_axis, y="normalized", hue=series , data=df,
                                height=10, kind="bar", palette="muted", aspect =1.3)

                ax = plt.gca()
                plt.show()
                print("yess sirr")


            elif placement == "series":
                print("nah bruh")
                plt.figure(figsize=(15,16)) 

                g = sns.pointplot(x=x_axis, y="normalized", hue=series, data=df,
                                     palette="muted")
                plt.show()
            
        elif normalized == False:
            
        
            if placement == 'grouped':

                g = sns.catplot(x=x_axis, y=y_axis, hue=series , data=df,
                                height=10, kind="bar", palette="muted", aspect =1.3)

                ax = plt.gca()
                plt.show()
                print("yess sirr")


            elif placement == "series":
                print("nah bruh")
                plt.figure(figsize=(15,16)) 

                g = sns.pointplot(x=x_axis, y=y_axis, hue=series, data=df,
                                     palette="muted")
                plt.show()


    elif df[x_axis].dtype == int or float:
        
        if normalized == True:
                     
            df = df.assign(normalized = df[y_axis].div(df[series].map(df.groupby([series])[y_axis].sum())))
            display(df.head())
        
            if placement == 'grouped':
                print("bars on bars")

                g = sns.catplot(x=x_axis, y="normalized", hue=series, data=df, legend=False,
                                height=10, kind="bar", palette="muted", aspect =1.3)

                ax = plt.gca()
                plt.show()


            elif placement == "series":
                print("lineplots for days")
                plt.figure(figsize=(15,16)) 

                g = sns.lineplot(x=x_axis, y="normalized",hue=series, data=df, legend=False)

                plt.show()
                
        elif normalized == False:

            if placement == 'grouped':
                print("bars on bars")

                g = sns.catplot(x=x_axis, y=y_axis, hue=series, data=df,
                                height=10, kind="bar", palette="muted", aspect =1.3)

                ax = plt.gca()
                plt.show()


            elif placement == "series":
                print("lineplots for days")
                plt.figure(figsize=(15,16)) 

                g = sns.lineplot(x=x_axis, y=y_axis,hue=series, data=df, legend=False)

                plt.show()

# %%
def one_df_distrib_v2(df, x_axis, y_axis, series, normalized = True, placement="grouped", universe="", subset=None):
    
    if not universe =="":
        df = df[~(df[x_axis]==universe)]
                 
    
    if subset is not None:
        user_one = input ("Enter sample size number: ")
        sample_size = int(user_one)
        print("Sample size selected is: ", sample_size)
        
        user_two = input ("Enter field name for sampling (i.e. Geography field) with no qoutations: ")
        subset_field = user_two
        print("Field selected is: ", subset_field)
        
        Geo_list = list(df[subset_field])
        geo_set = set(Geo_list)
        final_list = list(geo_set)
        #print(geo_set)
        
        sub_set=[i for i in random.sample(final_list,sample_size)]
        final_df = df[df[subset_field].isin(sub_set)]
        sub_set.sort()
        display(sub_set)

        for s in sub_set:
            df = final_df[final_df[subset_field]==s]
            #print(df)

            if df[x_axis].dtype == object:
                            

                if normalized == True:

                    df = df.assign(normalized = df[y_axis].div(df[series].map(df.groupby([series])[y_axis].sum())))
                    display(df.head())

                    if placement == 'grouped':

                        g = sns.catplot(x=x_axis, y="normalized", hue=series , data=df,
                                        height=10, kind="bar", palette="muted", aspect =1.3, legend=False)

                        ax = plt.gca()

                        #x.legend(loc='lower left' , mode="expand", bbox_to_anchor=(1.05,0.5))
                        ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                        mode="expand", borderaxespad=0, ncol=2)

                        plt.show()

                        print("yess sirr")


                    elif placement == "series":
                        print("nah bruh")
                        plt.figure(figsize=(15,16)) 

                        g = sns.pointplot(x=x_axis, y="normalized", hue=series, data=df,
                                             palette="muted")

                        ax = plt.gca()

                        #x.legend(loc='lower left' , mode="expand", bbox_to_anchor=(1.05,0.5))
                        ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                        mode="expand", borderaxespad=0, ncol=2)

                        plt.show()

                elif normalized == False:


                    if placement == 'grouped':

                        g = sns.catplot(x=x_axis, y=y_axis, hue=series , data=df,
                                        height=10, kind="bar", palette="muted", aspect =1.3, legend=False)

                        ax = plt.gca()


                        #x.legend(loc='lower left' , mode="expand", bbox_to_anchor=(1.05,0.5))
                        ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                        mode="expand", borderaxespad=0, ncol=2)

                        plt.show()
                        print("yess sirr")


                    elif placement == "series":
                        print("nah bruh")
                        plt.figure(figsize=(15,16)) 

                        g = sns.pointplot(x=x_axis, y=y_axis, hue=series, data=df,
                                             palette="muted")

                        ax = plt.gca()

                        #x.legend(loc='lower left' , mode="expand", bbox_to_anchor=(1.05,0.5))
                        ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                        mode="expand", borderaxespad=0, ncol=2)

                        plt.show()


            elif df[x_axis].dtype == int or float:
                
                if normalized == True:

                    df = df.assign(normalized = df[y_axis].div(df[series].map(df.groupby([series])[y_axis].sum())))
                    display(df.head())

                    if placement == 'grouped':
                        print("bars on bars")

                        g = sns.catplot(x=x_axis, y="normalized", hue=series, data=df, legend=False,
                                        height=10, kind="bar", palette="muted", aspect =1.3)

                        ax = plt.gca()
                        
                     
                            
                        #x.legend(loc='lower left' , mode="expand", bbox_to_anchor=(1.05,0.5))
                        ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                        mode="expand", borderaxespad=0, ncol=2)
                        
                        plt.show()


                    elif placement == "series":
                        print("lineplots for days")
                        plt.figure(figsize=(15,16)) 

                        g = sns.lineplot(x=x_axis, y="normalized",hue=series, data=df)
                        
                        ax = plt.gca()

                        #x.legend(loc='lower left' , mode="expand", bbox_to_anchor=(1.05,0.5))
                        ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                        mode="expand", borderaxespad=0, ncol=2)

                        plt.show()

                elif normalized == False:

                    if placement == 'grouped':
                        print("bars on bars")

                        g = sns.catplot(x=x_axis, y=y_axis, hue=series, data=df,
                                        height=10, kind="bar", palette="muted", aspect =1.3, legend=False)

                        ax = plt.gca()
                        
                        #x.legend(loc='lower left' , mode="expand", bbox_to_anchor=(1.05,0.5))
                        ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                        mode="expand", borderaxespad=0, ncol=2)
                        
                        plt.show()


                    elif placement == "series":
                        print("lineplots for days")
                        plt.figure(figsize=(15,16)) 

                        g = sns.lineplot(x=x_axis, y=y_axis,hue=series, data=df)
                        
                        ax = plt.gca()
                            
                        #x.legend(loc='lower left' , mode="expand", bbox_to_anchor=(1.05,0.5))
                        ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                        mode="expand", borderaxespad=0, ncol=2)

                        plt.show()

    else:

        if df[x_axis].dtype == object:
            

            if normalized == True:

                df = df.assign(normalized = df[y_axis].div(df[series].map(df.groupby([series])[y_axis].sum())))
                display(df.head())

                if placement == 'grouped':

                    g = sns.catplot(x=x_axis, y="normalized", hue=series , data=df,
                                    height=10, kind="bar", palette="muted", aspect =1.3, legend=False)

                    ax = plt.gca()

                    #x.legend(loc='lower left' , mode="expand", bbox_to_anchor=(1.05,0.5))
                    ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                    mode="expand", borderaxespad=0, ncol=2)

                    plt.show()

                    print("yess sirr")


                elif placement == "series":
                    print("nah bruh")
                    plt.figure(figsize=(15,16)) 

                    g = sns.pointplot(x=x_axis, y="normalized", hue=series, data=df,
                                         palette="muted")

                    ax = plt.gca()

                    #x.legend(loc='lower left' , mode="expand", bbox_to_anchor=(1.05,0.5))
                    ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                    mode="expand", borderaxespad=0, ncol=2)

                    plt.show()

            elif normalized == False:


                if placement == 'grouped':

                    g = sns.catplot(x=x_axis, y=y_axis, hue=series , data=df,
                                    height=10, kind="bar", palette="muted", aspect =1.3, legend=False)

                    ax = plt.gca()


                    #x.legend(loc='lower left' , mode="expand", bbox_to_anchor=(1.05,0.5))
                    ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                    mode="expand", borderaxespad=0, ncol=2)

                    plt.show()
                    print("yess sirr")


                elif placement == "series":
                    print("nah bruh")
                    plt.figure(figsize=(15,16)) 

                    g = sns.pointplot(x=x_axis, y=y_axis, hue=series, data=df,
                                         palette="muted")

                    ax = plt.gca()

                    #x.legend(loc='lower left' , mode="expand", bbox_to_anchor=(1.05,0.5))
                    ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                    mode="expand", borderaxespad=0, ncol=2)

                    plt.show()


        elif df[x_axis].dtype == int or float:
            
            if normalized == True:

                df = df.assign(normalized = df[y_axis].div(df[series].map(df.groupby([series])[y_axis].sum())))
                display(df.head())

                if placement == 'grouped':
                    print("bars on bars")

                    g = sns.catplot(x=x_axis, y="normalized", hue=series, data=df, legend=False,
                                    height=10, kind="bar", palette="muted", aspect =1.3)

                    ax = plt.gca()
                    
                 
                        
                    #x.legend(loc='lower left' , mode="expand", bbox_to_anchor=(1.05,0.5))
                    ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                    mode="expand", borderaxespad=0, ncol=2)
                    
                    plt.show()


                elif placement == "series":
                    print("lineplots for days")
                    plt.figure(figsize=(15,16)) 

                    g = sns.lineplot(x=x_axis, y="normalized",hue=series, data=df)
                    
                    ax = plt.gca()

                    #x.legend(loc='lower left' , mode="expand", bbox_to_anchor=(1.05,0.5))
                    ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                    mode="expand", borderaxespad=0, ncol=2)

                    plt.show()

            elif normalized == False:

                if placement == 'grouped':
                    print("bars on bars")

                    g = sns.catplot(x=x_axis, y=y_axis, hue=series, data=df,
                                    height=10, kind="bar", palette="muted", aspect =1.3, legend=False)

                    ax = plt.gca()
                    
                    #x.legend(loc='lower left' , mode="expand", bbox_to_anchor=(1.05,0.5))
                    ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                    mode="expand", borderaxespad=0, ncol=2)
                    
                    plt.show()


                elif placement == "series":
                    print("lineplots for days")
                    plt.figure(figsize=(15,16)) 

                    g = sns.lineplot(x=x_axis, y=y_axis,hue=series, data=df)
                    
                    ax = plt.gca()
                        
                    #x.legend(loc='lower left' , mode="expand", bbox_to_anchor=(1.05,0.5))
                    ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                    mode="expand", borderaxespad=0, ncol=2)

                    plt.show()

# %%
one_df_distrib_v2(ws_df2,"Year","Value","Control", False, "series", universe=2003)
# Out:
# lineplots for days

# %%
def one_df_distrib_v3(df, x_axis, y_axis, series, placement="grouped",output="raw", universe="", subset=None):
    
    pd.options.mode.chained_assignment = None
    if not universe =="":
        df = df[~(df[x_axis]==universe)]
                 
    #abs diff
    t = df.loc[:,[series,y_axis]].groupby(series).apply(lambda x: x.diff()).loc[:,y_axis]
    df['diff'] = t

    #percent diff
    df["pct_diff"]= df.groupby(series)[y_axis].apply(lambda x: x.diff()/x)


    #cumulative sum function by group
    df["cumulative"] = df.groupby(series)[y_axis].cumsum()
    
    
    
    if subset is not None:
        user_one = input ("Enter sample size number: ")
        sample_size = int(user_one)
        print("Sample size selected is: ", sample_size)
        
        user_two = input ("Enter field name for sampling (i.e. Geography field) with no qoutations: ")
        subset_field = user_two
        print("Field selected is: ", subset_field)
        
        Geo_list = list(df[subset_field])
        geo_set = set(Geo_list)
        final_list = list(geo_set)
        #print(geo_set)
        
        sub_set=[i for i in random.sample(final_list,sample_size)]
        final_df = df[df[subset_field].isin(sub_set)]
        sub_set.sort()
        display(sub_set)

        for s in sub_set:
            df = final_df[final_df[subset_field]==s]
            print(df)
        
              
   
            if df[x_axis].dtype == object:

                #create interval labels
                df["interval"]=df.groupby(series)[x_axis].transform(lambda x: x.shift(1) + "-" + x)
                display(df)
                print(series,y_axis)

                if placement == "grouped":

                    if output== "raw":

                        g = sns.catplot(x=x_axis, y=y_axis, hue=series , data=df,
                        height=10, kind="bar", palette="muted", aspect =1.3, legend=False)

                        ax = plt.gca()


                        #x.legend(loc='lower left' , mode="expand", bbox_to_anchor=(1.05,0.5))
                        ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                        mode="expand", borderaxespad=0, ncol=2)

                        plt.show()
                        print("Raw Values - Bar Plot")



                    elif output == "abs_diff":

                        df = df.loc[~(df["interval"].isna()),]

                        g = sns.catplot(x="interval", y="diff", hue=series , data=df,
                        height=10, kind="bar", palette="muted", aspect =1.3, legend=False)

                        ax = plt.gca()


                        #x.legend(loc='lower left' , mode="expand", bbox_to_anchor=(1.05,0.5))
                        ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                        mode="expand", borderaxespad=0, ncol=2)

                        plt.show()
                        print("Absolute Difference Values - Bar Plot")



                    elif output == "pct_diff":

                        df = df[~(df["interval"].isna())]

                        g = sns.catplot(x="interval", y="pct_diff", hue=series , data=df,
                        height=10, kind="bar", palette="muted", aspect =1.3, legend=False)

                        ax = plt.gca()


                        #x.legend(loc='lower left' , mode="expand", bbox_to_anchor=(1.05,0.5))
                        ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                        mode="expand", borderaxespad=0, ncol=2)

                        plt.show()
                        print("Percentage Difference Values - Bar Plot")

                    elif output == "cumulative":

                        g = sns.catplot(x=x_axis, y="cumulative", hue=series , data=df,
                        height=10, kind="bar", palette="muted", aspect =1.3, legend=False)

                        ax = plt.gca()


                        #x.legend(loc='lower left' , mode="expand", bbox_to_anchor=(1.05,0.5))
                        ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                        mode="expand", borderaxespad=0, ncol=2)

                        plt.show()
                        print("Cumulative Values - Bar Plot")

                elif placement == "series":


                    if output== "raw":

                        print("Raw Values - lineplots")
                        plt.figure(figsize=(15,16)) 

                        g = sns.pointplot(x=x_axis, y=y_axis, hue=series, data=df,
                                             palette="muted")

                        ax = plt.gca()

                        #x.legend(loc='lower left' , mode="expand", bbox_to_anchor=(1.05,0.5))
                        ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                        mode="expand", borderaxespad=0, ncol=2)

                        plt.show()




                    elif output == "abs_diff":

                        print("Absolute Differences - lineplots")
                        plt.figure(figsize=(15,16))

                        df = df.loc[~(df["interval"].isna()),] 

                        g = sns.pointplot(x="interval", y="diff", hue=series, data=df,
                                             palette="muted")

                        ax = plt.gca()

                        #x.legend(loc='lower left' , mode="expand", bbox_to_anchor=(1.05,0.5))
                        ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                        mode="expand", borderaxespad=0, ncol=2)

                        plt.show()


                    elif output == "pct_diff":

                        print("Percentage Differences - lineplots")
                        plt.figure(figsize=(15,16))

                        df = df[~(df["interval"].isna())] 

                        g = sns.pointplot(x="interval", y="pct_diff", hue=series, data=df,
                                             palette="muted")

                        ax = plt.gca()

                        #x.legend(loc='lower left' , mode="expand", bbox_to_anchor=(1.05,0.5))
                        ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                        mode="expand", borderaxespad=0, ncol=2)

                        plt.show()



                    elif output == "cumulative":

                        print("Cumulative Values - lineplots")
                        plt.figure(figsize=(15,16)) 

                        g = sns.pointplot(x=x_axis, y="cumulative", hue=series, data=df,
                                             palette="muted")

                        ax = plt.gca()

                        #x.legend(loc='lower left' , mode="expand", bbox_to_anchor=(1.05,0.5))
                        ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                        mode="expand", borderaxespad=0, ncol=2)

                        plt.show()



            elif df[x_axis].dtype == int or float:

                #create interval labels
                df["interval"]=df.groupby(series)[x_axis].transform(lambda x: x.shift(1).astype(str) + "-" + x.astype(str))

                display(df.head(15))


                if placement == "grouped":

                    if output== "raw":

                        g = sns.catplot(x=x_axis, y=y_axis, hue=series , data=df,
                        height=10, kind="bar", palette="muted", aspect =1.3, legend=False)

                        ax = plt.gca()


                        #x.legend(loc='lower left' , mode="expand", bbox_to_anchor=(1.05,0.5))
                        ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                        mode="expand", borderaxespad=0, ncol=2)

                        plt.show()
                        print("Raw Values - Bar Plot")



                    elif output == "abs_diff":

                        df = df[~(df["interval"].isna())]

                        g = sns.catplot(x="interval", y="diff", hue=series , data=df,
                        height=10, kind="bar", palette="muted", aspect =1.3, legend=False)

                        ax = plt.gca()


                        #x.legend(loc='lower left' , mode="expand", bbox_to_anchor=(1.05,0.5))
                        ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                        mode="expand", borderaxespad=0, ncol=2)

                        plt.show()
                        print("Absolute Difference Values - Bar Plot")



                    elif output == "pct_diff":

                        df = df[~(df["interval"].isna())]

                        g = sns.catplot(x="interval", y="pct_diff", hue=series , data=df,
                        height=10, kind="bar", palette="muted", aspect =1.3, legend=False)

                        ax = plt.gca()


                        #x.legend(loc='lower left' , mode="expand", bbox_to_anchor=(1.05,0.5))
                        ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                        mode="expand", borderaxespad=0, ncol=2)

                        plt.show()
                        print("Percentage Difference Values - Bar Plot")

                    elif output == "cumulative":

                        g = sns.catplot(x=x_axis, y="cumulative", hue=series , data=df,
                        height=10, kind="bar", palette="muted", aspect =1.3, legend=False)

                        ax = plt.gca()


                        #x.legend(loc='lower left' , mode="expand", bbox_to_anchor=(1.05,0.5))
                        ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                        mode="expand", borderaxespad=0, ncol=2)

                        plt.show()
                        print("Cumulative Values - Bar Plot")

                elif placement == "series":


                    if output== "raw":

                        print("Raw Values - lineplots")
                        plt.figure(figsize=(15,16)) 

                        g = sns.lineplot(x=x_axis, y=y_axis,hue=series, data=df)

                        ax = plt.gca()

                        #x.legend(loc='lower left' , mode="expand", bbox_to_anchor=(1.05,0.5))
                        ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                        mode="expand", borderaxespad=0, ncol=2)

                        plt.show()




                    elif output == "abs_diff":

                        print("Absolute Differences - lineplots")
                        plt.figure(figsize=(15,16))

                        df = df[~(df["interval"].isna())] 

                        g = sns.lineplot(x="interval", y="diff",hue=series, data=df)


                        ax = plt.gca()

                        #x.legend(loc='lower left' , mode="expand", bbox_to_anchor=(1.05,0.5))
                        ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                        mode="expand", borderaxespad=0, ncol=2)

                        plt.show()


                    elif output == "pct_diff":

                        print("Percentage Differences - lineplots")
                        plt.figure(figsize=(15,16))

                        df = df[~(df["interval"].isna())]

                        g = sns.lineplot(x="interval", y="pct_diff",hue=series, data=df) 


                        ax = plt.gca()

                        #x.legend(loc='lower left' , mode="expand", bbox_to_anchor=(1.05,0.5))
                        ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                        mode="expand", borderaxespad=0, ncol=2)

                        plt.show()



                    elif output == "cumulative":

                        print("Cumulative Values - lineplots")
                        plt.figure(figsize=(15,16))


                        g = sns.lineplot(x=x_axis, y="cumulative",hue=series, data=df) 


                        ax = plt.gca()

                        #x.legend(loc='lower left' , mode="expand", bbox_to_anchor=(1.05,0.5))
                        ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                        mode="expand", borderaxespad=0, ncol=2)

                        plt.show()
    
    else:
        
        if df[x_axis].dtype == object:
        
            #create interval labels
            df["interval"]=df.groupby(series)[x_axis].transform(lambda x: x.shift(1) + "-" + x)
            display(df)
            print(series,y_axis)

            if placement == "grouped":

                if output== "raw":

                    g = sns.catplot(x=x_axis, y=y_axis, hue=series , data=df,
                    height=10, kind="bar", palette="muted", aspect =1.3, legend=False)

                    ax = plt.gca()


                    #x.legend(loc='lower left' , mode="expand", bbox_to_anchor=(1.05,0.5))
                    ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                    mode="expand", borderaxespad=0, ncol=2)

                    plt.show()
                    print("Raw Values - Bar Plot")



                elif output == "abs_diff":

                    df = df.loc[~(df["interval"].isna()),]

                    g = sns.catplot(x="interval", y="diff", hue=series , data=df,
                    height=10, kind="bar", palette="muted", aspect =1.3, legend=False)

                    ax = plt.gca()


                    #x.legend(loc='lower left' , mode="expand", bbox_to_anchor=(1.05,0.5))
                    ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                    mode="expand", borderaxespad=0, ncol=2)

                    plt.show()
                    print("Absolute Difference Values - Bar Plot")



                elif output == "pct_diff":

                    df = df[~(df["interval"].isna())]

                    g = sns.catplot(x="interval", y="pct_diff", hue=series , data=df,
                    height=10, kind="bar", palette="muted", aspect =1.3, legend=False)

                    ax = plt.gca()


                    #x.legend(loc='lower left' , mode="expand", bbox_to_anchor=(1.05,0.5))
                    ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                    mode="expand", borderaxespad=0, ncol=2)

                    plt.show()
                    print("Percentage Difference Values - Bar Plot")

                elif output == "cumulative":

                    g = sns.catplot(x=x_axis, y="cumulative", hue=series , data=df,
                    height=10, kind="bar", palette="muted", aspect =1.3, legend=False)

                    ax = plt.gca()


                    #x.legend(loc='lower left' , mode="expand", bbox_to_anchor=(1.05,0.5))
                    ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                    mode="expand", borderaxespad=0, ncol=2)

                    plt.show()
                    print("Cumulative Values - Bar Plot")

            elif placement == "series":


                if output== "raw":

                    print("Raw Values - lineplots")
                    plt.figure(figsize=(15,16)) 

                    g = sns.pointplot(x=x_axis, y=y_axis, hue=series, data=df,
                                         palette="muted")

                    ax = plt.gca()

                    #x.legend(loc='lower left' , mode="expand", bbox_to_anchor=(1.05,0.5))
                    ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                    mode="expand", borderaxespad=0, ncol=2)

                    plt.show()




                elif output == "abs_diff":

                    print("Absolute Differences - lineplots")
                    plt.figure(figsize=(15,16))

                    df = df.loc[~(df["interval"].isna()),] 

                    g = sns.pointplot(x="interval", y="diff", hue=series, data=df,
                                         palette="muted")

                    ax = plt.gca()

                    #x.legend(loc='lower left' , mode="expand", bbox_to_anchor=(1.05,0.5))
                    ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                    mode="expand", borderaxespad=0, ncol=2)

                    plt.show()


                elif output == "pct_diff":

                    print("Percentage Differences - lineplots")
                    plt.figure(figsize=(15,16))

                    df = df[~(df["interval"].isna())] 

                    g = sns.pointplot(x="interval", y="pct_diff", hue=series, data=df,
                                         palette="muted")

                    ax = plt.gca()

                    #x.legend(loc='lower left' , mode="expand", bbox_to_anchor=(1.05,0.5))
                    ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                    mode="expand", borderaxespad=0, ncol=2)

                    plt.show()



                elif output == "cumulative":

                    print("Cumulative Values - lineplots")
                    plt.figure(figsize=(15,16)) 

                    g = sns.pointplot(x=x_axis, y="cumulative", hue=series, data=df,
                                         palette="muted")

                    ax = plt.gca()

                    #x.legend(loc='lower left' , mode="expand", bbox_to_anchor=(1.05,0.5))
                    ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                    mode="expand", borderaxespad=0, ncol=2)

                    plt.show()

               

        elif df[x_axis].dtype == int or float:

            #create interval labels
            df["interval"]=df.groupby(series)[x_axis].transform(lambda x: x.shift(1).astype(str) + "-" + x.astype(str))

            display(df.head(15))


            if placement == "grouped":

                if output== "raw":

                    g = sns.catplot(x=x_axis, y=y_axis, hue=series , data=df,
                    height=10, kind="bar", palette="muted", aspect =1.3, legend=False)

                    ax = plt.gca()


                    #x.legend(loc='lower left' , mode="expand", bbox_to_anchor=(1.05,0.5))
                    ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                    mode="expand", borderaxespad=0, ncol=2)

                    plt.show()
                    print("Raw Values - Bar Plot")



                elif output == "abs_diff":

                    df = df[~(df["interval"].isna())]

                    g = sns.catplot(x="interval", y="diff", hue=series , data=df,
                    height=10, kind="bar", palette="muted", aspect =1.3, legend=False)

                    ax = plt.gca()


                    #x.legend(loc='lower left' , mode="expand", bbox_to_anchor=(1.05,0.5))
                    ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                    mode="expand", borderaxespad=0, ncol=2)

                    plt.show()
                    print("Absolute Difference Values - Bar Plot")



                elif output == "pct_diff":

                    df = df[~(df["interval"].isna())]

                    g = sns.catplot(x="interval", y="pct_diff", hue=series , data=df,
                    height=10, kind="bar", palette="muted", aspect =1.3, legend=False)

                    ax = plt.gca()


                    #x.legend(loc='lower left' , mode="expand", bbox_to_anchor=(1.05,0.5))
                    ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                    mode="expand", borderaxespad=0, ncol=2)

                    plt.show()
                    print("Percentage Difference Values - Bar Plot")

                elif output == "cumulative":

                    g = sns.catplot(x=x_axis, y="cumulative", hue=series , data=df,
                    height=10, kind="bar", palette="muted", aspect =1.3, legend=False)

                    ax = plt.gca()


                    #x.legend(loc='lower left' , mode="expand", bbox_to_anchor=(1.05,0.5))
                    ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                    mode="expand", borderaxespad=0, ncol=2)

                    plt.show()
                    print("Cumulative Values - Bar Plot")

            elif placement == "series":


                if output== "raw":

                    print("Raw Values - lineplots")
                    plt.figure(figsize=(15,16)) 

                    g = sns.lineplot(x=x_axis, y=y_axis,hue=series, data=df)

                    ax = plt.gca()

                    #x.legend(loc='lower left' , mode="expand", bbox_to_anchor=(1.05,0.5))
                    ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                    mode="expand", borderaxespad=0, ncol=2)

                    plt.show()




                elif output == "abs_diff":

                    print("Absolute Differences - lineplots")
                    plt.figure(figsize=(15,16))

                    df = df[~(df["interval"].isna())] 

                    g = sns.lineplot(x="interval", y="diff",hue=series, data=df)


                    ax = plt.gca()

                    #x.legend(loc='lower left' , mode="expand", bbox_to_anchor=(1.05,0.5))
                    ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                    mode="expand", borderaxespad=0, ncol=2)

                    plt.show()


                elif output == "pct_diff":

                    print("Percentage Differences - lineplots")
                    plt.figure(figsize=(15,16))

                    df = df[~(df["interval"].isna())]

                    g = sns.lineplot(x="interval", y="pct_diff",hue=series, data=df) 


                    ax = plt.gca()

                    #x.legend(loc='lower left' , mode="expand", bbox_to_anchor=(1.05,0.5))
                    ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                    mode="expand", borderaxespad=0, ncol=2)

                    plt.show()



                elif output == "cumulative":

                    print("Cumulative Values - lineplots")
                    plt.figure(figsize=(15,16))


                    g = sns.lineplot(x=x_axis, y="cumulative",hue=series, data=df) 


                    ax = plt.gca()

                    #x.legend(loc='lower left' , mode="expand", bbox_to_anchor=(1.05,0.5))
                    ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                    mode="expand", borderaxespad=0, ncol=2)

                    plt.show()

# %%
one_df_distrib_v3(ws_df2,"Year","Value","Control", "series", "raw", universe="2003")
# Out:
#                                               Control  Region    Stream  Year  \
# 1              Investment Products - Short Term Paper  Canada  Interest  2004
# 2              Investment Products - Short Term Paper  Canada  Interest  2005
# 3              Investment Products - Short Term Paper  Canada  Interest  2006
# 4              Investment Products - Short Term Paper  Canada  Interest  2007
# 5              Investment Products - Short Term Paper  Canada  Interest  2008
# 6              Investment Products - Short Term Paper  Canada  Interest  2009
# 7              Investment Products - Short Term Paper  Canada  Interest  2010
# 8              Investment Products - Short Term Paper  Canada  Interest  2011
# 9              Investment Products - Short Term Paper  Canada  Interest  2012
# 10             Investment Products - Short Term Paper  Canada  Interest  2013
# 11             Investment Products - Short Term Paper  Canada  Interest  2014
# 12             Investment Products - Short Term Paper  Canada  Interest  2015
# 13             Investment Products - Short Term Paper  Canada  Interest  2016
# 14             Investment Products - Short Term Paper  Canada  Interest  2017
# 16         Investment Products - Canada Savings Bonds  Canada  Interest  2004
# 17         Investment Products - Canada Savings Bonds  Canada  Interest  2005
# 18         Investment Products - Canada Savings Bonds  Canada  Interest  2006
# 19         Investment Products - Canada Savings Bonds  Canada  Interest  2007
# 20         Investment Products - Canada Savings Bonds  Canada  Interest  2008
# 21         Investment Products - Canada Savings Bonds  Canada  Interest  2009
# 22         Investment Products - Canada Savings Bonds  Canada  Interest  2010
# 23         Investment Products - Canada Savings Bonds  Canada  Interest  2011
# 24         Investment Products - Canada Savings Bonds  Canada  Interest  2012
# 25         Investment Products - Canada Savings Bonds  Canada  Interest  2013
# 26         Investment Products - Canada Savings Bonds  Canada  Interest  2014
# 27         Investment Products - Canada Savings Bonds  Canada  Interest  2015
# 28         Investment Products - Canada Savings Bonds  Canada  Interest  2016
# 29         Investment Products - Canada Savings Bonds  Canada  Interest  2017
# 31               Investment Products - Mortgages Held  Canada  Interest  2004
# 32               Investment Products - Mortgages Held  Canada  Interest  2005
# ..                                                ...     ...       ...   ...
# 52  Investment Products - Segregated Funds - Divid...  Canada  Dividend  2008
# 53  Investment Products - Investment Funds - Divid...  Canada  Dividend  2005
# 54  Investment Products - Investment Funds - Divid...  Canada  Dividend  2006
# 55  Investment Products - Investment Funds - Divid...  Canada  Dividend  2007
# 56  Investment Products - Investment Funds - Divid...  Canada  Dividend  2008
# 57  Investment Products - Investment Funds - Divid...  Canada  Dividend  2009
# 58  Investment Products - Investment Funds - Divid...  Canada  Dividend  2010
# 59  Investment Products - Investment Funds - Divid...  Canada  Dividend  2011
# 60  Investment Products - Investment Funds - Divid...  Canada  Dividend  2012
# 61  Investment Products - Investment Funds - Divid...  Canada  Dividend  2013
# 62  Investment Products - Investment Funds - Divid...  Canada  Dividend  2014
# 63  Investment Products - Investment Funds - Divid...  Canada  Dividend  2015
# 64  Investment Products - Investment Funds - Divid...  Canada  Dividend  2016
# 65  Investment Products - Investment Funds - Divid...  Canada  Dividend  2017
# 66  Investment Products - Segregated Funds - Divid...  Canada  Dividend  2009
# 67  Investment Products - Segregated Funds - Divid...  Canada  Dividend  2010
# 68  Investment Products - Segregated Funds - Divid...  Canada  Dividend  2011
# 69  Investment Products - Segregated Funds - Divid...  Canada  Dividend  2012
# 71  Investment Products - Investment Funds - Inter...  Canada  Interest  2004
# 72  Investment Products - Investment Funds - Inter...  Canada  Interest  2005
# 73  Investment Products - Investment Funds - Inter...  Canada  Interest  2006
# 74  Investment Products - Investment Funds - Inter...  Canada  Interest  2007
# 75  Investment Products - Investment Funds - Inter...  Canada  Interest  2008
# 76  Investment Products - Investment Funds - Inter...  Canada  Interest  2009
# 77  Investment Products - Investment Funds - Inter...  Canada  Interest  2010
# 78  Investment Products - Investment Funds - Inter...  Canada  Interest  2011
# 79  Investment Products - Investment Funds - Inter...  Canada  Interest  2012
# 80  Investment Products - Investment Funds - Inter...  Canada  Interest  2013
# 81  Investment Products - Investment Funds - Inter...  Canada  Interest  2014
# 82  Investment Products - Investment Funds - Inter...  Canada  Interest  2015
#
#            Value                                             Source  \
# 1   3.416000e+09  Statistics Canada, National Balance Sheet (acc...
# 2   2.382000e+09  Statistics Canada, National Balance Sheet (acc...
# 3   4.821000e+09  Statistics Canada, National Balance Sheet (acc...
# 4   4.998000e+09  Statistics Canada, National Balance Sheet (acc...
# 5   7.543000e+09  Statistics Canada, National Balance Sheet (acc...
# 6   5.949000e+09  Statistics Canada, National Balance Sheet (acc...
# 7   4.420000e+09  Statistics Canada, National Balance Sheet (acc...
# 8   4.464000e+09  Statistics Canada, National Balance Sheet (acc...
# 9   4.839000e+09  Statistics Canada, National Balance Sheet (acc...
# 10  4.930000e+09  Statistics Canada, National Balance Sheet (acc...
# 11  5.076000e+09  Statistics Canada, National Balance Sheet (acc...
# 12  6.202000e+09  Statistics Canada, National Balance Sheet (acc...
# 13  5.686000e+09  Statistics Canada, National Balance Sheet (acc...
# 14  6.030000e+09  Statistics Canada, National Balance Sheet (acc...
# 16  2.033400e+10  Bank of Canada Banking and Financial Statistic...
# 17  1.791300e+10  Bank of Canada Banking and Financial Statistic...
# 18  1.556000e+10  Bank of Canada Banking and Financial Statistic...
# 19  1.303300e+10  Bank of Canada Banking and Financial Statistic...
# 20  1.222500e+10  Bank of Canada Banking and Financial Statistic...
# 21  1.218800e+10  Bank of Canada Banking and Financial Statistic...
# 22  1.075800e+10  Bank of Canada Banking and Financial Statistic...
# 23  9.453000e+09  Bank of Canada Banking and Financial Statistic...
# 24  8.157000e+09  Bank of Canada Banking and Financial Statistic...
# 25  6.972000e+09  Bank of Canada Banking and Financial Statistic...
# 26  6.159000e+09  Bank of Canada Banking and Financial Statistic...
# 27  5.593000e+09  Bank of Canada Banking and Financial Statistic...
# 28  5.149000e+09  Bank of Canada Banking and Financial Statistic...
# 29  3.504000e+09  Bank of Canada Banking and Financial Statistic...
# 31  6.559000e+09  Statistics Canada, National Balance Sheet (acc...
# 32  6.924000e+09  Statistics Canada, National Balance Sheet (acc...
# ..           ...                                                ...
# 52  6.305171e+10                                                NaN
# 53  3.570000e+11  Statistics Canada, National Balance Sheet (acc...
# 54  4.250000e+11  Statistics Canada, National Balance Sheet (acc...
# 55  4.580000e+11  Statistics Canada, National Balance Sheet (acc...
# 56  3.190000e+11  Statistics Canada, National Balance Sheet (acc...
# 57  4.070000e+11  Statistics Canada, National Balance Sheet (acc...
# 58  4.570000e+11  Statistics Canada, National Balance Sheet (acc...
# 59  4.340000e+11  Statistics Canada, National Balance Sheet (acc...
# 60  4.850000e+11  Statistics Canada, National Balance Sheet (acc...
# 61  5.890000e+11  Statistics Canada, National Balance Sheet (acc...
# 62  6.900000e+11  Statistics Canada, National Balance Sheet (acc...
# 63  7.520000e+11  Statistics Canada, National Balance Sheet (acc...
# 64  8.380000e+11  Statistics Canada, National Balance Sheet (acc...
# 65  9.710000e+11  Statistics Canada, National Balance Sheet (acc...
# 66  8.414911e+10                                                NaN
# 67  9.169764e+10                                                NaN
# 68  9.357493e+10                                                NaN
# 69  1.060000e+11                                                NaN
# 71  1.470000e+11  Statistics Canada, National Balance Sheet (acc...
# 72  1.670000e+11  Statistics Canada, National Balance Sheet (acc...
# 73  1.780000e+11  Statistics Canada, National Balance Sheet (acc...
# 74  1.850000e+11  Statistics Canada, National Balance Sheet (acc...
# 75  2.040000e+11  Statistics Canada, National Balance Sheet (acc...
# 76  2.010000e+11  Statistics Canada, National Balance Sheet (acc...
# 77  2.030000e+11  Statistics Canada, National Balance Sheet (acc...
# 78  2.330000e+11  Statistics Canada, National Balance Sheet (acc...
# 79  2.610000e+11  Statistics Canada, National Balance Sheet (acc...
# 80  2.830000e+11  Statistics Canada, National Balance Sheet (acc...
# 81  3.230000e+11  Statistics Canada, National Balance Sheet (acc...
# 82  3.490000e+11  Statistics Canada, National Balance Sheet (acc...
#
#                                      Notes          diff  pct_diff  \
# 1                                      NaN           NaN       NaN
# 2                                      NaN -1.034000e+09 -0.434089
# 3                                      NaN  2.439000e+09  0.505912
# 4                                      NaN  1.770000e+08  0.035414
# 5                                      NaN  2.545000e+09  0.337399
# 6                                      NaN -1.594000e+09 -0.267944
# 7                                      NaN -1.529000e+09 -0.345928
# 8                                      NaN  4.400000e+07  0.009857
# 9                                      NaN  3.750000e+08  0.077495
# 10                                     NaN  9.100000e+07  0.018458
# 11                                     NaN  1.460000e+08  0.028763
# 12                                     NaN  1.126000e+09  0.181554
# 13                                     NaN -5.160000e+08 -0.090749
# 14                                     NaN  3.440000e+08  0.057048
# 16                                     NaN           NaN       NaN
# 17                                     NaN -2.421000e+09 -0.135153
# 18                                     NaN -2.353000e+09 -0.151221
# 19                                     NaN -2.527000e+09 -0.193892
# 20                                     NaN -8.080000e+08 -0.066094
# 21                                     NaN -3.700000e+07 -0.003036
# 22                                     NaN -1.430000e+09 -0.132924
# 23                                     NaN -1.305000e+09 -0.138051
# 24                                     NaN -1.296000e+09 -0.158882
# 25                                     NaN -1.185000e+09 -0.169966
# 26                                     NaN -8.130000e+08 -0.132002
# 27                                     NaN -5.660000e+08 -0.101198
# 28                                     NaN -4.440000e+08 -0.086230
# 29                                     NaN -1.645000e+09 -0.469463
# 31                                     NaN           NaN       NaN
# 32                                     NaN  3.650000e+08  0.052715
# ..                                     ...           ...       ...
# 52  Now corrected to CLHIA control totals. -1.388512e+10 -0.220218
# 53                  BFS: $409,133,000,000.  6.800000e+10  0.190476
# 54                  BFS: $489,807,000,000.  6.800000e+10  0.160000
# 55                  BFS: $516,110,000,000.  3.300000e+10  0.072052
# 56                  BFS: $357,859,000,000. -1.390000e+11 -0.435737
# 57                  BFS: $455,184,000,000.  8.800000e+10  0.216216
# 58                  BFS: $522,324,000,000.  5.000000e+10  0.109409
# 59                  BFS: $495,228,000,000. -2.300000e+10 -0.052995
# 60                  BFS: $555,246,000,000.  5.100000e+10  0.105155
# 61                                     NaN  1.040000e+11  0.176570
# 62                                     NaN  1.010000e+11  0.146377
# 63                                     NaN  6.200000e+10  0.082447
# 64                                     NaN  8.600000e+10  0.102625
# 65                                     NaN  1.330000e+11  0.136972
# 66  Now corrected to CLHIA control totals.  2.109740e+10  0.250714
# 67  Now corrected to CLHIA control totals.  7.548530e+09  0.082320
# 68  Now corrected to CLHIA control totals.  1.877286e+09  0.020062
# 69  Now corrected to CLHIA control totals.  1.242507e+10  0.117218
# 71                  BFS: $165,885,000,000.           NaN       NaN
# 72                  BFS: $180,092,000,000.  2.000000e+10  0.119760
# 73                  BFS: $193,403,000,000.  1.100000e+10  0.061798
# 74                  BFS: $205,561,000,000.  7.000000e+09  0.037838
# 75                  BFS: $211,211,000,000.  1.900000e+10  0.093137
# 76                  BFS: $208,488,000,000. -3.000000e+09 -0.014925
# 77                  BFS: $210,590,000,000.  2.000000e+09  0.009852
# 78                  BFS: $223,920,000,000.  3.000000e+10  0.128755
# 79                  BFS: $243,539,000,000.  2.800000e+10  0.107280
# 80                                     NaN  2.200000e+10  0.077739
# 81                                     NaN  4.000000e+10  0.123839
# 82                                     NaN  2.600000e+10  0.074499
#
#       cumulative   interval
# 1   3.416000e+09        NaN
# 2   5.798000e+09  2004-2005
# 3   1.061900e+10  2005-2006
# 4   1.561700e+10  2006-2007
# 5   2.316000e+10  2007-2008
# 6   2.910900e+10  2008-2009
# 7   3.352900e+10  2009-2010
# 8   3.799300e+10  2010-2011
# 9   4.283200e+10  2011-2012
# 10  4.776200e+10  2012-2013
# 11  5.283800e+10  2013-2014
# 12  5.904000e+10  2014-2015
# 13  6.472600e+10  2015-2016
# 14  7.075600e+10  2016-2017
# 16  2.033400e+10        NaN
# 17  3.824700e+10  2004-2005
# 18  5.380700e+10  2005-2006
# 19  6.684000e+10  2006-2007
# 20  7.906500e+10  2007-2008
# 21  9.125300e+10  2008-2009
# 22  1.020110e+11  2009-2010
# 23  1.114640e+11  2010-2011
# 24  1.196210e+11  2011-2012
# 25  1.265930e+11  2012-2013
# 26  1.327520e+11  2013-2014
# 27  1.383450e+11  2014-2015
# 28  1.434940e+11  2015-2016
# 29  1.469980e+11  2016-2017
# 31  6.559000e+09        NaN
# 32  1.348300e+10  2004-2005
# ..           ...        ...
# 52  3.790594e+11  2007-2008
# 53  6.460000e+11  2004-2005
# 54  1.071000e+12  2005-2006
# 55  1.529000e+12  2006-2007
# 56  1.848000e+12  2007-2008
# 57  2.255000e+12  2008-2009
# 58  2.712000e+12  2009-2010
# 59  3.146000e+12  2010-2011
# 60  3.631000e+12  2011-2012
# 61  4.220000e+12  2012-2013
# 62  4.910000e+12  2013-2014
# 63  5.662000e+12  2014-2015
# 64  6.500000e+12  2015-2016
# 65  7.471000e+12  2016-2017
# 66  4.632085e+11  2008-2009
# 67  5.549061e+11  2009-2010
# 68  6.484811e+11  2010-2011
# 69  7.544811e+11  2011-2012
# 71  1.470000e+11        NaN
# 72  3.140000e+11  2004-2005
# 73  4.920000e+11  2005-2006
# 74  6.770000e+11  2006-2007
# 75  8.810000e+11  2007-2008
# 76  1.082000e+12  2008-2009
# 77  1.285000e+12  2009-2010
# 78  1.518000e+12  2010-2011
# 79  1.779000e+12  2011-2012
# 80  2.062000e+12  2012-2013
# 81  2.385000e+12  2013-2014
# 82  2.734000e+12  2014-2015
#
# [77 rows x 11 columns]
# Control Value
# Raw Values - lineplots

# %%
ws_df2 = pd.read_csv("wsct_subset.csv")
ws_df2.Year = ws_df2.Year.astype(str)

#ws_df2.groupby(["Control"]).size()
ws_df2.Year.dtype
# Out:
# dtype('O')

# %%
var = "Investment Products - Investment Funds - Dividend Bearing"

ws_df2[ws_df2["Control"]=="Investment Products - Investment Funds - Dividend Bearing"]
# Out:
#                                               Control  Region    Stream  Year  \
# 45  Investment Products - Investment Funds - Divid...  Canada  Dividend  2003
# 46  Investment Products - Investment Funds - Divid...  Canada  Dividend  2004
# 53  Investment Products - Investment Funds - Divid...  Canada  Dividend  2005
# 54  Investment Products - Investment Funds - Divid...  Canada  Dividend  2006
# 55  Investment Products - Investment Funds - Divid...  Canada  Dividend  2007
# 56  Investment Products - Investment Funds - Divid...  Canada  Dividend  2008
# 57  Investment Products - Investment Funds - Divid...  Canada  Dividend  2009
# 58  Investment Products - Investment Funds - Divid...  Canada  Dividend  2010
# 59  Investment Products - Investment Funds - Divid...  Canada  Dividend  2011
# 60  Investment Products - Investment Funds - Divid...  Canada  Dividend  2012
# 61  Investment Products - Investment Funds - Divid...  Canada  Dividend  2013
# 62  Investment Products - Investment Funds - Divid...  Canada  Dividend  2014
# 63  Investment Products - Investment Funds - Divid...  Canada  Dividend  2015
# 64  Investment Products - Investment Funds - Divid...  Canada  Dividend  2016
# 65  Investment Products - Investment Funds - Divid...  Canada  Dividend  2017
#
#            Value                                             Source  \
# 45  2.490000e+11  Statistics Canada, National Balance Sheet (acc...
# 46  2.890000e+11  Statistics Canada, National Balance Sheet (acc...
# 53  3.570000e+11  Statistics Canada, National Balance Sheet (acc...
# 54  4.250000e+11  Statistics Canada, National Balance Sheet (acc...
# 55  4.580000e+11  Statistics Canada, National Balance Sheet (acc...
# 56  3.190000e+11  Statistics Canada, National Balance Sheet (acc...
# 57  4.070000e+11  Statistics Canada, National Balance Sheet (acc...
# 58  4.570000e+11  Statistics Canada, National Balance Sheet (acc...
# 59  4.340000e+11  Statistics Canada, National Balance Sheet (acc...
# 60  4.850000e+11  Statistics Canada, National Balance Sheet (acc...
# 61  5.890000e+11  Statistics Canada, National Balance Sheet (acc...
# 62  6.900000e+11  Statistics Canada, National Balance Sheet (acc...
# 63  7.520000e+11  Statistics Canada, National Balance Sheet (acc...
# 64  8.380000e+11  Statistics Canada, National Balance Sheet (acc...
# 65  9.710000e+11  Statistics Canada, National Balance Sheet (acc...
#
#                      Notes
# 45  BFS: $291,400,000,000.
# 46  BFS: $347,512,000,000.
# 53  BFS: $409,133,000,000.
# 54  BFS: $489,807,000,000.
# 55  BFS: $516,110,000,000.
# 56  BFS: $357,859,000,000.
# 57  BFS: $455,184,000,000.
# 58  BFS: $522,324,000,000.
# 59  BFS: $495,228,000,000.
# 60  BFS: $555,246,000,000.
# 61                     NaN
# 62                     NaN
# 63                     NaN
# 64                     NaN
# 65                     NaN

# %%
one_df_distrib_v2(tranposed,"variable","value","Flag", True, "grouped", "PFTOT","yes")
#tranposed
# Out:
# Enter sample size number: 2
# Sample size selected is:  2
# Enter field name for sampling (i.e. Geography field) with no qoutations: CODE
# Field selected is:  CODE
# [59151979, 59370308]
#         CODE variable  value Flag  normalized
# 17  59151979   PF0004     22  new    0.066066
# 27  59151979   PF0509     21  new    0.063063
# 37  59151979   PF1014     16  new    0.048048
# 47  59151979   PF1519     14  new    0.042042
# 57  59151979   PF2024     19  new    0.057057
# yess sirr
#         CODE variable  value Flag  normalized
# 19  59370308   PF0004     11  new    0.046809
# 29  59370308   PF0509     12  new    0.051064
# 39  59370308   PF1014     12  new    0.051064
# 49  59370308   PF1519      9  new    0.038298
# 59  59370308   PF2024      8  new    0.034043
# yess sirr

# %%
one_df_distrib_v3(tranposed,"variable","value","Flag", "grouped", "raw", "PFTOT","yes")
#tranposed
# Out:
# Enter sample size number: 2
# Sample size selected is:  2
# Enter field name for sampling (i.e. Geography field) with no qoutations: CODE
# Field selected is:  CODE
# [24450149, 48111620]
#          CODE variable  value Flag  diff  pct_diff  cumulative
# 10   24450149   PF0004      9  new   NaN       NaN           9
# 20   24450149   PF0509     11  new   0.0  0.000000         144
# 30   24450149   PF1014     14  new   2.0  0.142857         301
# 40   24450149   PF1519     14  new   2.0  0.142857         441
# 50   24450149   PF2024      9  new   0.0  0.000000         585
# 60   24450149   PF2529     11  new   3.0  0.272727         737
# 70   24450149   PF3034     13  new   6.0  0.461538         883
# 80   24450149   PF3539     15  new   4.0  0.266667        1060
# 90   24450149   PF4044     13  new  -2.0 -0.153846        1274
# 100  24450149   PF4549      9  new  -7.0 -0.777778        1453
# 110  24450149   PF5054     14  new   3.0  0.214286        1633
# 120  24450149   PF5559     20  new  10.0  0.500000        1835
# 130  24450149   PF6064     22  new  11.0  0.500000        2064
# 140  24450149   PF6569     18  new   7.0  0.388889        2265
# 150  24450149   PF7074     19  new   4.0  0.210526        2455
# 160  24450149   PF7579     13  new  -8.0 -0.615385        2616
# 170  24450149   PF8084      5  new -15.0 -3.000000        2723
# 180  24450149    PF85P      6  new -11.0 -1.833333        2795
# 200  24450149   PF0004      9  old   NaN       NaN           9
# 210  24450149   PF0509     12  old   0.0  0.000000         148
# 220  24450149   PF1014     14  old   2.0  0.142857         306
# 230  24450149   PF1519     14  old   2.0  0.142857         443
# 240  24450149   PF2024     10  old   2.0  0.200000         589
# 250  24450149   PF2529     11  old   3.0  0.272727         740
# 260  24450149   PF3034     14  old   7.0  0.500000         887
# 270  24450149   PF3539     15  old   3.0  0.200000        1068
# 280  24450149   PF4044     12  old  -3.0 -0.250000        1281
# 290  24450149   PF4549      8  old  -8.0 -1.000000        1457
# 300  24450149   PF5054     16  old   6.0  0.375000        1640
# 310  24450149   PF5559     22  old  12.0  0.545455        1849
# 320  24450149   PF6064     21  old  10.0  0.476190        2080
# 330  24450149   PF6569     18  old   7.0  0.388889        2276
# 340  24450149   PF7074     20  old   4.0  0.200000        2464
# 350  24450149   PF7579     11  old -11.0 -1.000000        2619
# 360  24450149   PF8084      5  old -14.0 -2.800000        2723
# 370  24450149    PF85P      6  old -11.0 -1.833333        2793
#          CODE variable  value Flag  diff  pct_diff  cumulative       interval
# 10   24450149   PF0004      9  new   NaN       NaN           9            NaN
# 20   24450149   PF0509     11  new   0.0  0.000000         144  PF0004-PF0509
# 30   24450149   PF1014     14  new   2.0  0.142857         301  PF0509-PF1014
# 40   24450149   PF1519     14  new   2.0  0.142857         441  PF1014-PF1519
# 50   24450149   PF2024      9  new   0.0  0.000000         585  PF1519-PF2024
# 60   24450149   PF2529     11  new   3.0  0.272727         737  PF2024-PF2529
# 70   24450149   PF3034     13  new   6.0  0.461538         883  PF2529-PF3034
# 80   24450149   PF3539     15  new   4.0  0.266667        1060  PF3034-PF3539
# 90   24450149   PF4044     13  new  -2.0 -0.153846        1274  PF3539-PF4044
# 100  24450149   PF4549      9  new  -7.0 -0.777778        1453  PF4044-PF4549
# 110  24450149   PF5054     14  new   3.0  0.214286        1633  PF4549-PF5054
# 120  24450149   PF5559     20  new  10.0  0.500000        1835  PF5054-PF5559
# 130  24450149   PF6064     22  new  11.0  0.500000        2064  PF5559-PF6064
# 140  24450149   PF6569     18  new   7.0  0.388889        2265  PF6064-PF6569
# 150  24450149   PF7074     19  new   4.0  0.210526        2455  PF6569-PF7074
# 160  24450149   PF7579     13  new  -8.0 -0.615385        2616  PF7074-PF7579
# 170  24450149   PF8084      5  new -15.0 -3.000000        2723  PF7579-PF8084
# 180  24450149    PF85P      6  new -11.0 -1.833333        2795   PF8084-PF85P
# 200  24450149   PF0004      9  old   NaN       NaN           9            NaN
# 210  24450149   PF0509     12  old   0.0  0.000000         148  PF0004-PF0509
# 220  24450149   PF1014     14  old   2.0  0.142857         306  PF0509-PF1014
# 230  24450149   PF1519     14  old   2.0  0.142857         443  PF1014-PF1519
# 240  24450149   PF2024     10  old   2.0  0.200000         589  PF1519-PF2024
# 250  24450149   PF2529     11  old   3.0  0.272727         740  PF2024-PF2529
# 260  24450149   PF3034     14  old   7.0  0.500000         887  PF2529-PF3034
# 270  24450149   PF3539     15  old   3.0  0.200000        1068  PF3034-PF3539
# 280  24450149   PF4044     12  old  -3.0 -0.250000        1281  PF3539-PF4044
# 290  24450149   PF4549      8  old  -8.0 -1.000000        1457  PF4044-PF4549
# 300  24450149   PF5054     16  old   6.0  0.375000        1640  PF4549-PF5054
# 310  24450149   PF5559     22  old  12.0  0.545455        1849  PF5054-PF5559
# 320  24450149   PF6064     21  old  10.0  0.476190        2080  PF5559-PF6064
# 330  24450149   PF6569     18  old   7.0  0.388889        2276  PF6064-PF6569
# 340  24450149   PF7074     20  old   4.0  0.200000        2464  PF6569-PF7074
# 350  24450149   PF7579     11  old -11.0 -1.000000        2619  PF7074-PF7579
# 360  24450149   PF8084      5  old -14.0 -2.800000        2723  PF7579-PF8084
# 370  24450149    PF85P      6  old -11.0 -1.833333        2793   PF8084-PF85P
# Flag value
# Raw Values - Bar Plot
#          CODE variable  value Flag  diff  pct_diff  cumulative
# 15   48111620   PF0004     25  new   9.0  0.360000          77
# 25   48111620   PF0509     32  new  20.0  0.625000         226
# 35   48111620   PF1014     28  new  24.0  0.857143         364
# 45   48111620   PF1519     33  new  23.0  0.696970         522
# 55   48111620   PF2024     25  new  12.0  0.480000         670
# 65   48111620   PF2529     29  new   9.0  0.310345         827
# 75   48111620   PF3034     32  new   9.0  0.281250         980
# 85   48111620   PF3539     44  new  26.0  0.590909        1172
# 95   48111620   PF4044     31  new  18.0  0.580645        1366
# 105  48111620   PF4549     26  new  12.0  0.461538        1547
# 115  48111620   PF5054     32  new   8.0  0.250000        1749
# 125  48111620   PF5559     36  new  10.0  0.277778        1967
# 135  48111620   PF6064     33  new  10.0  0.303030        2169
# 145  48111620   PF6569     50  new  39.0  0.780000        2363
# 155  48111620   PF7074     36  new  27.0  0.750000        2535
# 165  48111620   PF7579     14  new   5.0  0.357143        2668
# 175  48111620   PF8084      6  new   3.0  0.500000        2750
# 185  48111620    PF85P      3  new   2.0  0.666667        2813
# 205  48111620   PF0004     25  old   8.0  0.320000          79
# 215  48111620   PF0509     33  old  21.0  0.636364         231
# 225  48111620   PF1014     28  old  25.0  0.892857         367
# 235  48111620   PF1519     33  old  22.0  0.666667         525
# 245  48111620   PF2024     25  old  12.0  0.480000         675
# 255  48111620   PF2529     31  old   9.0  0.290323         832
# 265  48111620   PF3034     32  old   9.0  0.281250         985
# 275  48111620   PF3539     44  old  27.0  0.613636        1178
# 285  48111620   PF4044     30  old  17.0  0.566667        1372
# 295  48111620   PF4549     26  old  11.0  0.423077        1553
# 305  48111620   PF5054     34  old   9.0  0.264706        1760
# 315  48111620   PF5559     37  old  10.0  0.270270        1984
# 325  48111620   PF6064     33  old  11.0  0.333333        2179
# 335  48111620   PF6569     51  old  42.0  0.823529        2372
# 345  48111620   PF7074     33  old  24.0  0.727273        2541
# 355  48111620   PF7579     12  old   2.0  0.166667        2669
# 365  48111620   PF8084      6  old   4.0  0.666667        2748
# 375  48111620    PF85P      3  old   3.0  1.000000        2811
#          CODE variable  value Flag  diff  pct_diff  cumulative       interval
# 15   48111620   PF0004     25  new   9.0  0.360000          77            NaN
# 25   48111620   PF0509     32  new  20.0  0.625000         226  PF0004-PF0509
# 35   48111620   PF1014     28  new  24.0  0.857143         364  PF0509-PF1014
# 45   48111620   PF1519     33  new  23.0  0.696970         522  PF1014-PF1519
# 55   48111620   PF2024     25  new  12.0  0.480000         670  PF1519-PF2024
# 65   48111620   PF2529     29  new   9.0  0.310345         827  PF2024-PF2529
# 75   48111620   PF3034     32  new   9.0  0.281250         980  PF2529-PF3034
# 85   48111620   PF3539     44  new  26.0  0.590909        1172  PF3034-PF3539
# 95   48111620   PF4044     31  new  18.0  0.580645        1366  PF3539-PF4044
# 105  48111620   PF4549     26  new  12.0  0.461538        1547  PF4044-PF4549
# 115  48111620   PF5054     32  new   8.0  0.250000        1749  PF4549-PF5054
# 125  48111620   PF5559     36  new  10.0  0.277778        1967  PF5054-PF5559
# 135  48111620   PF6064     33  new  10.0  0.303030        2169  PF5559-PF6064
# 145  48111620   PF6569     50  new  39.0  0.780000        2363  PF6064-PF6569
# 155  48111620   PF7074     36  new  27.0  0.750000        2535  PF6569-PF7074
# 165  48111620   PF7579     14  new   5.0  0.357143        2668  PF7074-PF7579
# 175  48111620   PF8084      6  new   3.0  0.500000        2750  PF7579-PF8084
# 185  48111620    PF85P      3  new   2.0  0.666667        2813   PF8084-PF85P
# 205  48111620   PF0004     25  old   8.0  0.320000          79            NaN
# 215  48111620   PF0509     33  old  21.0  0.636364         231  PF0004-PF0509
# 225  48111620   PF1014     28  old  25.0  0.892857         367  PF0509-PF1014
# 235  48111620   PF1519     33  old  22.0  0.666667         525  PF1014-PF1519
# 245  48111620   PF2024     25  old  12.0  0.480000         675  PF1519-PF2024
# 255  48111620   PF2529     31  old   9.0  0.290323         832  PF2024-PF2529
# 265  48111620   PF3034     32  old   9.0  0.281250         985  PF2529-PF3034
# 275  48111620   PF3539     44  old  27.0  0.613636        1178  PF3034-PF3539
# 285  48111620   PF4044     30  old  17.0  0.566667        1372  PF3539-PF4044
# 295  48111620   PF4549     26  old  11.0  0.423077        1553  PF4044-PF4549
# 305  48111620   PF5054     34  old   9.0  0.264706        1760  PF4549-PF5054
# 315  48111620   PF5559     37  old  10.0  0.270270        1984  PF5054-PF5559
# 325  48111620   PF6064     33  old  11.0  0.333333        2179  PF5559-PF6064
# 335  48111620   PF6569     51  old  42.0  0.823529        2372  PF6064-PF6569
# 345  48111620   PF7074     33  old  24.0  0.727273        2541  PF6569-PF7074
# 355  48111620   PF7579     12  old   2.0  0.166667        2669  PF7074-PF7579
# 365  48111620   PF8084      6  old   4.0  0.666667        2748  PF7579-PF8084
# 375  48111620    PF85P      3  old   3.0  1.000000        2811   PF8084-PF85P
# Flag value
# Raw Values - Bar Plot

# %%
tranposed.to_csv('transposed.csv', index=False)

# %%
tranposed = pd.read_csv("transposed.csv")
